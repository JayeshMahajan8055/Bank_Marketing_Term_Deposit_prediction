# %% [markdown]
# # Bank Marketing Term Deposit Prediction
#
# This project analyzes the Bank Marketing dataset to predict whether a client will subscribe to a term deposit. The workflow includes data loading, preprocessing, exploratory data analysis, feature engineering, and building machine learning models to classify client responses. The dataset contains information about direct marketing campaigns of a Portuguese banking institution, including client and campaign attributes. The goal is to build a predictive model to assist the bank in targeting potential clients more effectively.

# %% [markdown]
# ## About the Dataset
#
# The Bank Marketing dataset contains information collected from direct marketing campaigns of a Portuguese banking institution. The data includes client attributes (such as age, job, marital status), campaign details (number of contacts, previous outcomes), and economic indicators. The target variable is whether the client subscribed to a term deposit ('yes' or 'no').
#
# ## Project Workflow
#
# 1. Data Loading and Exploration
# 2. Data Cleaning and Preprocessing
# 3. Exploratory Data Analysis (EDA)
# 4. Feature Engineering
# 5. Model Building and Evaluation
# 6. Insights and Conclusions
#
# This notebook will guide you through each step, providing code, visualizations, and explanations to help understand the process and results.

# %% [markdown]
# ## Input and Output Variables
#
# ### Input Variables (Features)
# - **age**: Age of the client (numeric)
# - **job**: Type of job (categorical)
# - **marital**: Marital status (categorical)
# - **education**: Education level (categorical)
# - **default**: Has credit in default? (categorical)
# - **housing**: Has housing loan? (categorical)
# - **loan**: Has personal loan? (categorical)
# - **contact**: Contact communication type (categorical)
# - **month**: Last contact month of year (categorical)
# - **day_of_week**: Last contact day of the week (categorical)
# - **duration**: Last contact duration, in seconds (numeric)
# - **campaign**: Number of contacts performed during this campaign (numeric)
# - **pdays**: Days since last contact from a previous campaign (numeric)
# - **previous**: Number of contacts before this campaign (numeric)
# - **poutcome**: Outcome of the previous marketing campaign (categorical)
# - **emp.var.rate**: Employment variation rate (numeric)
# - **cons.price.idx**: Consumer price index (numeric)
# - **cons.conf.idx**: Consumer confidence index (numeric)
# - **euribor3m**: Euribor 3 month rate (numeric)
# - **nr.employed**: Number of employees (numeric)
#
# ### Output Variable (Target)
# - **y**: Has the client subscribed a term deposit? (binary: 'yes', 'no')

# %%
# Load libraries
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
data = pd.read_csv(r"C:\Users\Jayesh Mahajan\Desktop\bank_project\bank-additional\bank-additional\bank-additional-full.csv", sep=';')
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %% [markdown]
# Drop duration column dis attribute highly affects the output target (e.g., if duration=0 then y='no').
# Yet, the duration is not non before a call is performed. Also, after the end of the call y is obviously non.Thus, dis input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.

# %%
data=pd.read_csv(r"C:\Users\Jayesh Mahajan\Desktop\bank_project\bank-additional\bank-additional\bank-additional-full.csv",sep=';')
data=data.drop(['duration'],axis=1)
print(data.shape)
data.head()
# Out:
# (41188, 20)
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon         1    999         0  nonexistent           1.1
# 1   may         mon         1    999         0  nonexistent           1.1
# 2   may         mon         1    999         0  nonexistent           1.1
# 3   may         mon         1    999         0  nonexistent           1.1
# 4   may         mon         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no

# %%
data.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  campaign  pdays  previous     poutcome  \
# 41183  cellular   nov         fri         1    999         0  nonexistent
# 41184  cellular   nov         fri         1    999         0  nonexistent
# 41185  cellular   nov         fri         2    999         0  nonexistent
# 41186  cellular   nov         fri         1    999         0  nonexistent
# 41187  cellular   nov         fri         3    999         1      failure
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# 41183          -1.1          94.767          -50.8      1.028       4963.6
# 41184          -1.1          94.767          -50.8      1.028       4963.6
# 41185          -1.1          94.767          -50.8      1.028       4963.6
# 41186          -1.1          94.767          -50.8      1.028       4963.6
# 41187          -1.1          94.767          -50.8      1.028       4963.6
#
#          y
# 41183  yes
# 41184   no
# 41185   no
# 41186  yes
# 41187   no

# %% [markdown]
# # 2. Data Exploration

# %%
#Information of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  campaign        41188 non-null  int64
#  11  pdays           41188 non-null  int64
#  12  previous        41188 non-null  int64
#  13  poutcome        41188 non-null  object
#  14  emp.var.rate    41188 non-null  float64
#  15  cons.price.idx  41188 non-null  float64
#  16  cons.conf.idx   41188 non-null  float64
#  17  euribor3m       41188 non-null  float64
#  18  nr.employed     41188 non-null  float64
#  19  y               41188 non-null  object
# dtypes: float64(5), int64(4), object(11)
# memory usage: 6.3+ MB

# %%
data.describe()
# Out:
#                age      campaign         pdays      previous  emp.var.rate  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406      2.567593    962.475454      0.172963      0.081886
# std       10.42125      2.770014    186.910907      0.494901      1.570960
# min       17.00000      1.000000      0.000000      0.000000     -3.400000
# 25%       32.00000      1.000000    999.000000      0.000000     -1.800000
# 50%       38.00000      2.000000    999.000000      0.000000      1.100000
# 75%       47.00000      3.000000    999.000000      0.000000      1.400000
# max       98.00000     56.000000    999.000000      7.000000      1.400000
#
#        cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count    41188.000000   41188.000000  41188.000000  41188.000000
# mean        93.575664     -40.502600      3.621291   5167.035911
# std          0.578840       4.628198      1.734447     72.251528
# min         92.201000     -50.800000      0.634000   4963.600000
# 25%         93.075000     -42.700000      1.344000   5099.100000
# 50%         93.749000     -41.800000      4.857000   5191.000000
# 75%         93.994000     -36.400000      4.961000   5228.100000
# max         94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# # 1.1. Knowing the categorical variables

# %%
# knowing the job categorical variables
data["job"].unique()
# Out:
# array(['housemaid', 'services', 'admin.', 'blue-collar', 'technician',
#        'retired', 'management', 'unemployed', 'self-employed', 'unknown',
#        'entrepreneur', 'student'], dtype=object)

# %%
# knowing the age categorical variables
data["age"].unique()
# Out:
# array([56, 57, 37, 40, 45, 59, 41, 24, 25, 29, 35, 54, 46, 50, 39, 30, 55,
#        49, 34, 52, 58, 32, 38, 44, 42, 60, 53, 47, 51, 48, 33, 31, 43, 36,
#        28, 27, 26, 22, 23, 20, 21, 61, 19, 18, 70, 66, 76, 67, 73, 88, 95,
#        77, 68, 75, 63, 80, 62, 65, 72, 82, 64, 71, 69, 78, 85, 79, 83, 81,
#        74, 17, 87, 91, 86, 98, 94, 84, 92, 89])

# %%
data["marital"].unique()
# Out:
# array(['married', 'single', 'divorced', 'unknown'], dtype=object)

# %%
data["education"].unique()
# Out:
# array(['basic.4y', 'high.school', 'basic.6y', 'basic.9y',
#        'professional.course', 'unknown', 'university.degree',
#        'illiterate'], dtype=object)

# %% [markdown]
# We first start the exploratory analysis of the categorical variables and see what are the categories and are there any missing values for these categories. Here, we used the seaborn package to create the bar graphs below.

# %%
# we will not emp.var.rate ,cons.price.idx etc into consideration due to they are all single value.here we are taking only categorial value into consideration.
categori=['job', 'marital', 'education', 'default','housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome','y']
for col in categori:
    plt.figure(figsize=(11,6))
    sns.barplot(x=data[col].value_counts().index, y=data[col].value_counts().values)
    plt.title(col)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Input Categorical feature Observation

# %% [markdown]
# 1) Job - More Job types are Admin , Technician and blue-collor and it means bank targeting high salaried people.
#
# 2)Marital - more people of type married - (#To Do - Check the target value distribution for high salaried married people)
#
# 3) Education - more count in university.degree people . of course High salaried people should have university degree
#  expected. And illiterate count is very less.
#
# 4) default - most people have no credit default ,which means they can be approched .
#
# 5) housing - we must give more importance to people who have not taken any housing loan.
#
# 6)loan - we must give more importance to people who have not taken any personnel loan.
#
# 7) month - Seems May is busy season in Portuguese
#
# 8) Day_of_week - Seems every day is busy but not on weekends.
#
# 9) p_outcome -outcome of the previous marketing campaign- Success is small rate. (#To DO - Check how success correlates without put parameter ?)

# %% [markdown]
# # Categorize variables correlated with Target Variables

# %%
#Check How Categorize variables correlated with Target Variables and How it impacted.
from scipy import stats

# %%
#Check How Job Type correlated with Target Variable
data.groupby(['job','y']).y.count()

#Admin are more interested in Term Deposit.
# Out:
# job            y
# admin.         no     9070
#                yes    1352
# blue-collar    no     8616
#                yes     638
# entrepreneur   no     1332
#                yes     124
# housemaid      no      954
#                yes     106
# management     no     2596
#                yes     328
# retired        no     1286
#                yes     434
# self-employed  no     1272
#                yes     149
# services       no     3646
#                yes     323
# student        no      600
#                yes     275
# technician     no     6013
#                yes     730
# unemployed     no      870
#                yes     144
# unknown        no      293
#                yes      37
# Name: y, dtype: int64

# %%
#Normalized distribution of each class per feature and plotted difference between positive and negative frequencies.
#Positive values imply this category favors clients that will subscribe and negative values categories that favor not buying the 
#product.
feature_name = 'job'

# ======================================================================================================

pos_counts = data.loc[data.y.values == 'yes', feature_name].value_counts() 
neg_counts = data.loc[data.y.values == 'no', feature_name].value_counts()
    
all_counts = list(set(list(pos_counts.index) + list(neg_counts.index)))
    
#Counts of how often each outcome was recorded.
freq_pos = (data.y.values == 'yes').sum()
freq_neg = (data.y.values == 'no').sum()
    
pos_counts = pos_counts.to_dict()
neg_counts = neg_counts.to_dict()
    
all_index = list(all_counts)
# angelaxuan/dna-brown-bag-session-bank-marketing-campaign
all_counts = [pos_counts.get(k, 0) / freq_pos - neg_counts.get(k, 0) / freq_neg for k in all_counts]

sns.barplot(x=all_index, y=all_counts)  
plt.title(feature_name)
plt.tight_layout()

# %%
data.groupby(['marital','y']).y.count()
#married people are more interested in Term Deposit
# Out:
# marital   y
# divorced  no      4136
#           yes      476
# married   no     22396
#           yes     2532
# single    no      9948
#           yes     1620
# unknown   no        68
#           yes       12
# Name: y, dtype: int64

# %%
for feature_name in categori:
    # Calculate frequency of positive and negative outcomes
    freq_pos = (data.y.values == 'yes').sum()
    freq_neg = (data.y.values == 'no').sum()
    
    # Get value counts for each feature
    pos_counts = data.loc[data.y.values == 'yes', feature_name].value_counts() 
    neg_counts = data.loc[data.y.values == 'no', feature_name].value_counts()
    
    # Get all unique categories for this feature
    all_counts = list(set(list(pos_counts.index) + list(neg_counts.index)))
    
    # Convert to dictionaries for easier access
    pos_counts = pos_counts.to_dict()
    neg_counts = neg_counts.to_dict()
    
    # Calculate normalized differences
    all_index = list(all_counts)
    all_counts_values = [pos_counts.get(k, 0) / freq_pos - neg_counts.get(k, 0) / freq_neg for k in all_counts]
    
    # Create the plot
    plt.figure(figsize=(10, 6))
    sns.barplot(x=all_index, y=all_counts_values)
    plt.title(f'Normalized Difference for {feature_name}')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
data.groupby(['job','marital','y']).y.count()
# And Admin - married people are more interested in Term Deposit.
# Out:
# job      marital   y
# admin.   divorced  no     1148
#                    yes     132
#          married   no     4601
#                    yes     652
#          single    no     3309
#                           ...
# unknown  married   yes      16
#          single    no       59
#                    yes      15
#          unknown   no        6
#                    yes       3
# Name: y, Length: 90, dtype: int64

# %%
data.groupby(['contact','y']).y.count()
#Contact field has good correlation with Target variable. Since we have two observation for contact lets convert this to binary format. cellular -1 and telephone=0
# Out:
# contact    y
# cellular   no     22291
#            yes     3853
# telephone  no     14257
#            yes      787
# Name: y, dtype: int64

# %%
feature_name = 'contact'

pos_freq = data[data.y == 'yes'].groupby([feature_name]).size()
neg_freq = data[data.y == 'no'].groupby([feature_name]).size()
freq_pos = data[data.y == 'yes'].shape[0]
freq_neg = data[data.y == 'no'].shape[0]

pos_counts = dict(pos_freq)
neg_counts = dict(neg_freq)

print(pos_counts)
print(neg_counts)

all_counts = set(pos_counts.keys()).union(set(neg_counts.keys()))

print(all_counts)

all_index = list(all_counts)
all_counts = [pos_counts.get(k, 0) / freq_pos - neg_counts.get(k, 0) / freq_neg for k in all_counts]

sns.barplot(x=all_index, y=all_counts)
plt.title(feature_name)
plt.tight_layout()
plt.show()
# Out:
# {'cellular': np.int64(3853), 'telephone': np.int64(787)}
# {'cellular': np.int64(22291), 'telephone': np.int64(14257)}
# {'telephone', 'cellular'}

# %%
data.groupby(['day_of_week','y']).age.count()
# Out:
# day_of_week  y
# fri          no     6981
#              yes     846
# mon          no     7667
#              yes     847
# thu          no     7578
#              yes    1045
# tue          no     7137
#              yes     953
# wed          no     7185
#              yes     949
# Name: age, dtype: int64

# %%
feature_name = 'day_of_week'

# Counts for positive ("yes") and negative ("no") outcomes
pos_counts = data.loc[data.y.values == 'yes', feature_name].value_counts()
neg_counts = data.loc[data.y.values == 'no', feature_name].value_counts()

# All unique category labels
all_labels = list(set(pos_counts.index.tolist() + neg_counts.index.tolist()))

# Total number of positive and negative outcomes
freq_pos = (data.y.values == 'yes').sum()
freq_neg = (data.y.values == 'no').sum()

# Convert counts to dictionaries for lookup
pos_counts = pos_counts.to_dict()
neg_counts = neg_counts.to_dict()

# Difference between normalized frequencies
differences = [
    pos_counts.get(label, 0) / freq_pos - neg_counts.get(label, 0) / freq_neg
    for label in all_labels
]

# Create DataFrame for plotting
plot_df = pd.DataFrame({
    feature_name: all_labels,
    'difference': differences
})

# Optional: sort by difference for better readability
plot_df = plot_df.sort_values('difference', ascending=False)

# Plot
sns.barplot(x='difference', y=feature_name, data=plot_df)
plt.axvline(0, color='black', linewidth=1)  # vertical line at 0
plt.title(feature_name)
plt.tight_layout()
plt.show()

# %%
data.groupby(['loan','y']).age.count()
# Out:
# loan     y
# no       no     30100
#          yes     3850
# unknown  no       883
#          yes      107
# yes      no      5565
#          yes      683
# Name: age, dtype: int64

# %%
#Normalized distribution of each class per feature and plotted difference between positive and negative frequencies.
#Positive values imply this category favors clients that will subscribe and negative values categories that favor not buying the 
#product.
feature_name = 'loan'

# ======================================================================================================

pos_counts = data.loc[data.y.values == 'yes', feature_name].value_counts() 
neg_counts = data.loc[data.y.values == 'no', feature_name].value_counts()
    
all_counts = list(set(list(pos_counts.index) + list(neg_counts.index)))
    
#Counts of how often each outcome was recorded.
freq_pos = (data.y.values == 'yes').sum()
freq_neg = (data.y.values == 'no').sum()
    
pos_counts = pos_counts.to_dict()
neg_counts = neg_counts.to_dict()
    
all_index = list(all_counts)
all_counts = [pos_counts.get(k, 0) / freq_pos - neg_counts.get(k, 0) / freq_neg for k in all_counts]
sns.barplot(x=all_index, y=all_counts)  

plt.title(feature_name)
plt.tight_layout()

# %%
data.groupby(['default','y']).age.count()
# Out:
# default  y
# no       no     28391
#          yes     4197
# unknown  no      8154
#          yes      443
# yes      no         3
# Name: age, dtype: int64

# %%
#Normalized distribution of each class per feature and plotted difference between positive and negative frequencies.
#Positive values imply this category favors clients that will subscribe and negative values categories that favor not buying the 
#product.
feature_name = 'default'

# ======================================================================================================

pos_counts = data.loc[data.y.values == 'yes', feature_name].value_counts() 
neg_counts = data.loc[data.y.values == 'no', feature_name].value_counts()
    
all_counts = list(set(list(pos_counts.index) + list(neg_counts.index)))
    
#Counts of how often each outcome was recorded.
freq_pos = (data.y.values == 'yes').sum()
freq_neg = (data.y.values == 'no').sum()
    
pos_counts = pos_counts.to_dict()
neg_counts = neg_counts.to_dict()
    
all_index = list(all_counts)
all_counts = [pos_counts.get(k, 0) / freq_pos - neg_counts.get(k, 0) / freq_neg for k in all_counts]

sns.barplot(x=all_index, y=all_counts)  
plt.title(feature_name)
plt.tight_layout()

# %%
data.groupby(['housing','y']).age.count()
# Out:
# housing  y
# no       no     16596
#          yes     2026
# unknown  no       883
#          yes      107
# yes      no     19069
#          yes     2507
# Name: age, dtype: int64

# %%
#Normalized distribution of each class per feature and plotted difference between positive and negative frequencies.
#Positive values imply this category favors clients that will subscribe and negative values categories that favor not buying the 
#product.
feature_name = 'housing'

# ======================================================================================================

pos_counts = data.loc[data.y.values == 'yes', feature_name].value_counts() 
neg_counts = data.loc[data.y.values == 'no', feature_name].value_counts()
    
all_counts = list(set(list(pos_counts.index) + list(neg_counts.index)))
    
#Counts of how often each outcome was recorded.
freq_pos = (data.y.values == 'yes').sum()
freq_neg = (data.y.values == 'no').sum()
    
pos_counts = pos_counts.to_dict()
neg_counts = neg_counts.to_dict()
    
all_index = list(all_counts)
all_counts = [pos_counts.get(k, 0) / freq_pos - neg_counts.get(k, 0) / freq_neg for k in all_counts]

sns.barplot(x=all_index, y=all_counts)  
plt.title(feature_name)
plt.tight_layout()

# %%
data.groupby(['poutcome','y']).age.count()
# Out:
# poutcome     y
# failure      no      3647
#              yes      605
# nonexistent  no     32422
#              yes     3141
# success      no       479
#              yes      894
# Name: age, dtype: int64

# %%
#Normalized distribution of each class per feature and plotted difference between positive and negative frequencies.
#Positive values imply this category favors clients that will subscribe and negative values categories that favor not buying the 
#product.
feature_name = 'poutcome'

# ======================================================================================================

pos_counts = data.loc[data.y.values == 'yes', feature_name].value_counts() 
neg_counts = data.loc[data.y.values == 'no', feature_name].value_counts()
    
all_counts = list(set(list(pos_counts.index) + list(neg_counts.index)))
    
#Counts of how often each outcome was recorded.
freq_pos = (data.y.values == 'yes').sum()
freq_neg = (data.y.values == 'no').sum()
    
pos_counts = pos_counts.to_dict()
neg_counts = neg_counts.to_dict()
    
all_index = list(all_counts)
all_counts = [pos_counts.get(k, 0) / freq_pos - neg_counts.get(k, 0) / freq_neg for k in all_counts]
sns.barplot(x=all_index, y=all_counts)  
plt.title(feature_name)
plt.tight_layout()

# %%
data.groupby(['month','y']).age.count()
# Out:
# month  y
# apr    no      2093
#        yes      539
# aug    no      5523
#        yes      655
# dec    no        93
#        yes       89
# jul    no      6525
#        yes      649
# jun    no      4759
#        yes      559
# mar    no       270
#        yes      276
# may    no     12883
#        yes      886
# nov    no      3685
#        yes      416
# oct    no       403
#        yes      315
# sep    no       314
#        yes      256
# Name: age, dtype: int64

# %%
#Normalized distribution of each class per feature and plotted difference between positive and negative frequencies.
#Positive values imply this category favors clients that will subscribe and negative values categories that favor not buying the 
#product.
feature_name = 'month'

# ======================================================================================================

pos_counts = data.loc[data.y.values == 'yes', feature_name].value_counts() 
neg_counts = data.loc[data.y.values == 'no', feature_name].value_counts()
    
all_counts = list(set(list(pos_counts.index) + list(neg_counts.index)))
    
#Counts of how often each outcome was recorded.
freq_pos = (data.y.values == 'yes').sum()
freq_neg = (data.y.values == 'no').sum()
    
pos_counts = pos_counts.to_dict()
neg_counts = neg_counts.to_dict()
    
all_index = list(all_counts)
all_counts = [pos_counts.get(k, 0) / freq_pos - neg_counts.get(k, 0) / freq_neg for k in all_counts]

sns.barplot(x=all_index, y=all_counts)  
plt.title(feature_name)
plt.tight_layout()

# %%
#Normalized distribution of each class per feature and plotted difference between positive and negative frequencies.
#Positive values imply this category favors clients that will subscribe and negative values categories that favor not buying the 
#product.
feature_name = 'y'

# ======================================================================================================

pos_counts = data.loc[data.y.values == 'yes', feature_name].value_counts() 
neg_counts = data.loc[data.y.values == 'no', feature_name].value_counts()
    
all_counts = list(set(list(pos_counts.index) + list(neg_counts.index)))
    
#Counts of how often each outcome was recorded.
freq_pos = (data.y.values == 'yes').sum()
freq_neg = (data.y.values == 'no').sum()
    
pos_counts = pos_counts.to_dict()
neg_counts = neg_counts.to_dict()
    
all_index = list(all_counts)
all_counts = [pos_counts.get(k, 0) / freq_pos - neg_counts.get(k, 0) / freq_neg for k in all_counts]

sns.barplot(x=all_index, y=all_counts)  
plt.title(feature_name)
plt.tight_layout()

# %% [markdown]
# Inference/Result: There are unknown values for many variables in the Data set. There are many ways to handle missing data. One of the ways is to discard the row but that would lead to reduction of data set and hence would not serve our purpose of building an accurate and realistic prediction model.
#
# 2)Other method is to smartly infer the value of the unknown variable from the other variables. This a way of doing an imputation where we use other independent variables to infer the value of the missing variable. This doesn't gurantee that all missing values will be addressed but majority of them will have a reasonable which can be useful in the prediction.
#
# 3)Variables with unknown/missing values are : 'education', 'job', 'housing', 'loan', 'deafult', and 'marital'. But the significant ones are 'education', 'job', 'housing', and 'loan'. The number of unknowns for 'marital' is very low. The unknown for 'default' variable are considered to be recorded as unknown. It may be possible that customer is not willing to disclose this information to the banking representative. Hence the unknown value in 'default' is actually a separate value.
#
# 4) Therefore, we start with creating new variables for the unknown values in 'education', 'job', 'housing' and 'loan'. We do this to see if the values are missing at random or is there a pattern in the missing values.

# %% [markdown]
# # splitting of data

# %%
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon         1    999         0  nonexistent           1.1
# 1   may         mon         1    999         0  nonexistent           1.1
# 2   may         mon         1    999         0  nonexistent           1.1
# 3   may         mon         1    999         0  nonexistent           1.1
# 4   may         mon         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no

# %%
from sklearn.model_selection import train_test_split

# %%
# Saperating features and result vectors
y=data[['y']]
X = data.drop(['y'], axis=1)
#y = data['y'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
X_test.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
X_train.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
y_train.head()
# Out:
#         y
# 39075  no
# 34855  no
# 7107   no
# 31614  no
# 34878  no

# %%
y_test.head()
# Out:
#         y
# 32884  no
# 3169   no
# 32206  no
# 9403   no
# 14020  no

# %% [markdown]
# # Distribution of train and test data

# %%
def plot_distribution(class_distribution,title,xlabel,ylabel):
    class_distribution.plot(kind='bar')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.grid()
    plt.show()


# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = y_train['y'].value_counts()
test_class_distribution = y_test['y'].value_counts()


plot_distribution(train_class_distribution,
                 'Distribution of y_i in train data',
                 'Class',
                 'Data points per Class')

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], 
          '(', np.round((train_class_distribution.values[i]/X_train.shape[0]*100), 3), '%)')
    
print('-'*80)
# Out:
# Number of data points in class 1 : 25580 ( 88.724 %)
# Number of data points in class 2 : 3251 ( 11.276 %)
# --------------------------------------------------------------------------------

# %%
plot_distribution(test_class_distribution,
                 'Distribution of y_i in test data',
                 'Class',
                 'Data points per Class')

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(test_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], 
          '(', np.round((test_class_distribution.values[i]/X_test.shape[0]*100), 3), '%)')

print('-'*80)
# Out:
# Number of data points in class 1 : 10968 ( 88.759 %)
# Number of data points in class 2 : 1389 ( 11.241 %)
# --------------------------------------------------------------------------------

# %% [markdown]
# Distribution of both train and test data are same

# %%
# concatinate train data for data manupulation
data = pd.concat([X_train, y_train], axis=1)

# %%
data.head()
# Out:
#        age          job  marital          education  default housing loan  \
# 39075   29       admin.  married  university.degree       no      no   no
# 34855   29   technician   single  university.degree       no      no   no
# 7107    45  blue-collar  married           basic.6y  unknown     yes   no
# 31614   34     services  married  university.degree       no      no   no
# 34878   32       admin.   single        high.school       no      no   no
#
#          contact month day_of_week  campaign  pdays  previous     poutcome  \
# 39075   cellular   dec         mon         3    999         1      failure
# 34855  telephone   may         fri         4    999         0  nonexistent
# 7107   telephone   may         thu         2    999         0  nonexistent
# 31614   cellular   may         thu         1    999         1      failure
# 34878   cellular   may         fri         9    999         0  nonexistent
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 39075          -3.0          92.713          -33.0      0.709       5023.5  no
# 34855          -1.8          92.893          -46.2      1.250       5099.1  no
# 7107            1.1          93.994          -36.4      4.860       5191.0  no
# 31614          -1.8          92.893          -46.2      1.327       5099.1  no
# 34878          -1.8          92.893          -46.2      1.250       5099.1  no

# %%
# concatinate test data for data manupulation
data_1= pd.concat([X_test, y_test], axis=1)

# %%
data_1.head()
# Out:
#        age          job  marital    education  default housing loan  \
# 32884   57   technician  married  high.school       no      no  yes
# 3169    55      unknown  married      unknown  unknown     yes   no
# 32206   33  blue-collar  married     basic.9y       no      no   no
# 9403    36       admin.  married  high.school       no      no   no
# 14020   27    housemaid  married  high.school       no     yes   no
#
#          contact month day_of_week  campaign  pdays  previous     poutcome  \
# 32884   cellular   may         mon         1    999         1      failure
# 3169   telephone   may         thu         2    999         0  nonexistent
# 32206   cellular   may         fri         1    999         1      failure
# 9403   telephone   jun         fri         4    999         0  nonexistent
# 14020   cellular   jul         fri         2    999         0  nonexistent
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 32884          -1.8          92.893          -46.2      1.299       5099.1  no
# 3169            1.1          93.994          -36.4      4.860       5191.0  no
# 32206          -1.8          92.893          -46.2      1.313       5099.1  no
# 9403            1.4          94.465          -41.8      4.967       5228.1  no
# 14020           1.4          93.918          -42.7      4.963       5228.1  no

# %% [markdown]
# # Imputation:

# %% [markdown]
# Now, to infer the missing values in 'job' and 'education', we make use of the cross-tabulation between 'job' and 'education'. Our hypothesis here is that 'job' is influenced by the 'education' of a person. Hence, we can infer 'job' based on the education of the person. Moreover, since we are just filling the missing values, we are not much concerned about the causal inference. We, therefore, can use the job to predict the education.

# %%
def cross_tab(data,f1,f2):
    # find no of unique values in jobs colums
    jobs=list(data[f1].unique())
    # find no of unique values in education columns
    edu=list(data[f2].unique())
    dataframes=[]
    for e in edu:
        dfe=data[data[f2]==e]
        # https://www.youtube.com/watch?v=qy0fDqoMJx8 for groupby operation
        #https://www.youtube.com/watch?v=hfDXRyYIFkk grupby count
        #https://data36.com/pandas-tutorial-2-aggregation-and-grouping/
        dfejob=dfe.groupby(f1).count()[f2]
        dataframes.append(dfejob)
        #https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html
    xx=pd.concat(dataframes,axis=1)
    xx.columns=edu
    xx=xx.fillna(0)
    return xx

# %%
cross_tab(data,'job','education')
# Out:
#                university.degree  basic.6y  high.school  basic.4y  \
# job
# admin.                      4038       111         2344        57
# blue-collar                   62      1010          620      1658
# entrepreneur                 410        42          161        91
# housemaid                    102        59          128       329
# management                  1421        57          208        58
# retired                      185        50          204       411
# self-employed                550        16           77        64
# services                     118       153         1913        86
# student                      124        11          263        16
# technician                  1300        62          592        38
# unemployed                   183        21          183        71
# unknown                       37        15           25        35
#
#                professional.course  basic.9y  unknown  illiterate
# job
# admin.                         263       345      180         0.0
# blue-collar                    308      2528      310         4.0
# entrepreneur                    93       146       43         2.0
# housemaid                       48        61       26         1.0
# management                      66       119       85         0.0
# retired                        167        92       69         2.0
# self-employed                  122       160       25         2.0
# services                       155       268      116         0.0
# student                         34        65      125         0.0
# technician                    2271       243      150         0.0
# unemployed                     111       117       16         0.0
# unknown                         10        23       91         0.0

# %% [markdown]
# - Inferring education from jobs : From the cross-tabulation, it can be seen that people with management jobs usually have a university degree. Hence wherever 'job' = management and 'education' = unknown, we can replace 'education' with 'university.degree'. Similarly, 'job' = 'services' --> 'education' = 'high.school' and 'job' = 'housemaid' --> 'education' = 'basic.4y'.
#
# - Inferring jobs from education : If 'education' = 'basic.4y' or 'basic.6y' or 'basic.9y' then the 'job' is usually 'blue-collar'. If 'education' = 'professional.course', then the 'job' = 'technician'.
#
# - While imputing the values for job and education, we were cognizant of the fact that the correlations should make real world sense. If it didn't make real world sense, we didn't replace the missing values.

# %%
data['job'][data['age']>60].value_counts()
# Out:
# job
# retired          472
# housemaid         40
# admin.            33
# technician        26
# unknown           17
# management        16
# blue-collar       15
# unemployed         7
# self-employed      7
# entrepreneur       6
# services           2
# Name: count, dtype: int64

# %% [markdown]
# Inferring jobs from age: As we see, if 'age' > 60, then the 'job' is 'retired,' which makes sense.

# %%
data.loc[(data['age']>60) & (data['job']=='unknown'), 'job'] = 'retired'
data.loc[(data['education']=='unknown') & (data['job']=='management'), 'education'] = 'university.degree'
data.loc[(data['education']=='unknown') & (data['job']=='services'), 'education'] = 'high.school'
data.loc[(data['education']=='unknown') & (data['job']=='housemaid'), 'education'] = 'basic.4y'
data.loc[(data['job'] == 'unknown') & (data['education']=='basic.4y'), 'job'] = 'blue-collar'
data.loc[(data['job'] == 'unknown') & (data['education']=='basic.6y'), 'job'] = 'blue-collar'
data.loc[(data['job'] == 'unknown') & (data['education']=='basic.9y'), 'job'] = 'blue-collar'
data.loc[(data['job']=='unknown') & (data['education']=='professional.course'), 'job'] = 'technician'

# %%
#youtube.com/watch?v=I_kUj-MfYys use of cross tab
cross_tab(data,'job','education')
# Out:
#                university.degree  basic.6y  high.school  basic.4y  \
# job
# admin.                      4038     111.0         2344      57.0
# blue-collar                   62    1025.0          620    1690.0
# entrepreneur                 410      42.0          161      91.0
# housemaid                    102      59.0          128     355.0
# management                  1506      57.0          208      58.0
# retired                      186      50.0          204     414.0
# self-employed                550      16.0           77      64.0
# services                     118     153.0         2029      86.0
# student                      124      11.0          263      16.0
# technician                  1300      62.0          592      38.0
# unemployed                   183      21.0          183      71.0
# unknown                       36       0.0           25       0.0
#
#                professional.course  basic.9y  unknown  illiterate
# job
# admin.                       263.0     345.0    180.0         0.0
# blue-collar                  308.0    2551.0    310.0         4.0
# entrepreneur                  93.0     146.0     43.0         2.0
# housemaid                     48.0      61.0      0.0         1.0
# management                    66.0     119.0      0.0         0.0
# retired                      169.0      92.0     80.0         2.0
# self-employed                122.0     160.0     25.0         2.0
# services                     155.0     268.0      0.0         0.0
# student                       34.0      65.0    125.0         0.0
# technician                  2279.0     243.0    150.0         0.0
# unemployed                   111.0     117.0     16.0         0.0
# unknown                        0.0       0.0     80.0         0.0

# %% [markdown]
# As we can see, we are able to reduce the number of unknowns and enhance our data set.

# %% [markdown]
# # Imputations
# Imputation for house and loan : We are again using cross-tabulation between 'house' and 'job' and between 'loan' and 'job.' Our hypothesis is that housing loan status (Yes or No) should be in the proportion of each job category. Hence using the prior known distribution of the housing loan for each job category, the house loan for unknown people will be predicted such that the prior distribution (% House = Yes's and No's for each job category remains the same). Similarly, we have filled the missing values in the 'loan' variable.

# %%
jobhousing=cross_tab(data,'job','housing')
print(jobhousing)
# Out:
#                  no   yes  unknown
# job
# admin.         3280  3889      169
# blue-collar    3062  3326      182
# entrepreneur    444   517       27
# housemaid       356   381       17
# management      939  1030       45
# retired         547   614       36
# self-employed   461   527       28
# services       1280  1464       65
# student         271   349       18
# technician     2035  2526      103
# unemployed      284   398       20
# unknown          62    75        4

# %%
def fillhousing(data,jobhousing):
    """Function for imputation via cross-tabulation to fill missing values for the 'housing' categorical feature"""
    jobs=['housemaid','services','admin.','blue-collar','technician','retired','management','unemployed','self-employed','entrepreneur','student']
    house=["no","yes"]
    for j in jobs:
        #Here we are taking value in which housing is unknow and job value is known
        ind=data[np.logical_and(np.array(data['housing']=='unknown'),np.array(data['job']==j))].index
        mask=np.random.rand(len(ind))<((jobhousing.loc[j]['no'])/(jobhousing.loc[j]['no']+jobhousing.loc[j]['yes']))
        ind1=ind[mask]
        ind2=ind[~mask]
        data.loc[ind1,"housing"]='no'
        data.loc[ind2,"housing"]='yes'
    return data

# %%
data=fillhousing(data,jobhousing)

# %%
jobhousing=cross_tab(data,'job','housing')
print(jobhousing)
# Out:
#                  no   yes  unknown
# job
# admin.         3361  3977      0.0
# blue-collar    3146  3424      0.0
# entrepreneur    457   531      0.0
# housemaid       363   391      0.0
# management      965  1049      0.0
# retired         564   633      0.0
# self-employed   479   537      0.0
# services       1319  1490      0.0
# student         277   361      0.0
# technician     2078  2586      0.0
# unemployed      290   412      0.0
# unknown          62    75      4.0

# %% [markdown]
# # Imputation for personnel loan and loan

# %%
jobloan=cross_tab(data,'job','loan')
print(jobloan)
# Out:
#                  no   yes  unknown
# job
# admin.         5968  1201      169
# blue-collar    5413   975      182
# entrepreneur    810   151       27
# housemaid       635   102       17
# management     1670   299       45
# retired         986   175       36
# self-employed   849   139       28
# services       2300   444       65
# student         522    98       18
# technician     3880   681      103
# unemployed      586    96       20
# unknown         114    23        4

# %%
def fillloan(data,jobloan):
    """Function for imputation via cross-tabulation to fill missing values for the 'loan' categorical feature"""
    jobs=['housemaid','services','admin.','blue-collar','technician','retired','management','unemployed','self-employed','entrepreneur','student']
    loan=["no","yes"]
    for j in jobs:
        ind=data[np.logical_and(np.array(data['loan']=='unknown'),np.array(data['job']==j))].index
        mask=np.random.rand(len(ind))<((jobloan.loc[j]['no'])/(jobloan.loc[j]['no']+jobloan.loc[j]['yes']))
        ind1=ind[mask]
        ind2=ind[~mask]
        data.loc[ind1,"loan"]='no'
        data.loc[ind2,"loan"]='yes'
    return data

# %%
data=fillloan(data,jobloan)

# %%
jobloan=cross_tab(data,'job','loan')
print(jobloan)
# Out:
#                  no   yes  unknown
# job
# admin.         6102  1236      0.0
# blue-collar    5564  1006      0.0
# entrepreneur    833   155      0.0
# housemaid       652   102      0.0
# management     1708   306      0.0
# retired        1017   180      0.0
# self-employed   873   143      0.0
# services       2354   455      0.0
# student         537   101      0.0
# technician     3965   699      0.0
# unemployed      603    99      0.0
# unknown         114    23      4.0

# %% [markdown]
# # Numerical variables:

# %% [markdown]
# Let see the summary of the data in order to understand the numerical variables

# %%
numerical_variables = ['age','campaign', 'pdays', 'previous', 'emp.var.rate', 'cons.price.idx','cons.conf.idx','euribor3m',
                      'nr.employed']
data[numerical_variables].describe()
# Out:
#                 age      campaign         pdays      previous  emp.var.rate  \
# count  28831.000000  28831.000000  28831.000000  28831.000000  28831.000000
# mean      40.011203      2.575769    963.215844      0.172592      0.083202
# std       10.450128      2.752303    185.077567      0.494338      1.570978
# min       17.000000      1.000000      0.000000      0.000000     -3.400000
# 25%       32.000000      1.000000    999.000000      0.000000     -1.800000
# 50%       38.000000      2.000000    999.000000      0.000000      1.100000
# 75%       47.000000      3.000000    999.000000      0.000000      1.400000
# max       98.000000     43.000000    999.000000      7.000000      1.400000
#
#        cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count    28831.000000   28831.000000  28831.000000  28831.000000
# mean        93.577264     -40.515091      3.621599   5167.011880
# std          0.579694       4.634864      1.735202     72.542598
# min         92.201000     -50.800000      0.634000   4963.600000
# 25%         93.075000     -42.700000      1.344000   5099.100000
# 50%         93.749000     -41.800000      4.857000   5191.000000
# 75%         93.994000     -36.400000      4.961000   5228.100000
# max         94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# - Missing Values: From the source of the data (U.C. Irvine ML Repository), we're told that the missing values, or NaNs, are encoded as '999'. From the above table, it is clear that only 'pdays' has missing values. Moreover, a majority of the values for 'pdays' are missing.

# %%
data.head()
# Out:
#        age          job  marital          education  default housing loan  \
# 39075   29       admin.  married  university.degree       no      no   no
# 34855   29   technician   single  university.degree       no      no   no
# 7107    45  blue-collar  married           basic.6y  unknown     yes   no
# 31614   34     services  married  university.degree       no      no   no
# 34878   32       admin.   single        high.school       no      no   no
#
#          contact month day_of_week  campaign  pdays  previous     poutcome  \
# 39075   cellular   dec         mon         3    999         1      failure
# 34855  telephone   may         fri         4    999         0  nonexistent
# 7107   telephone   may         thu         2    999         0  nonexistent
# 31614   cellular   may         thu         1    999         1      failure
# 34878   cellular   may         fri         9    999         0  nonexistent
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 39075          -3.0          92.713          -33.0      0.709       5023.5  no
# 34855          -1.8          92.893          -46.2      1.250       5099.1  no
# 7107            1.1          93.994          -36.4      4.860       5191.0  no
# 31614          -1.8          92.893          -46.2      1.327       5099.1  no
# 34878          -1.8          92.893          -46.2      1.250       5099.1  no

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# #Balancing y out

# %%
sns.countplot(x='y',data=data)
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %% [markdown]
# We can see that the data is very skewed, so we duplicate the tuples corresponding to 'yes'

# %%
d1=data.copy()
d2=d1[d1.y=='yes']
d1=pd.concat([d1, d2])
d1=pd.concat([d1, d2])
d1=pd.concat([d1, d2])
d1=pd.concat([d1, d2])
d1=pd.concat([d1, d2])
d1=pd.concat([d1, d2])
d1=pd.concat([d1, d2])
data=d1

# %%
sns.countplot(x='y',data=data)
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %% [markdown]
# # Missing Values in Numerical Variables

# %% [markdown]
# Let's examine the missing values in 'pdays'

# %%
def drawhist(data,feature):
    plt.hist(data[feature])

# %% [markdown]
# Filtered out missing values encoded with an out-of-range value when plotting the histogram of values in order to properly understand the distribution of the known values. Here, histograms were created using matplotlib.

# %%
drawhist(data,'pdays')
plt.show()

plt.hist(data.loc[data.pdays != 999, 'pdays'])
plt.show()

# %%
#https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.crosstab.html
#Compute a simple cross-tabulation of two (or more) factors
pd.crosstab(data['pdays'],data['poutcome'], values=data['age'], aggfunc='count', normalize=True)
# Out:
# poutcome   failure  nonexistent   success
# pdays
# 0         0.000000     0.000000  0.001124
# 1         0.000000     0.000000  0.001182
# 2         0.000000     0.000000  0.003683
# 3         0.000019     0.000000  0.034446
# 4         0.000174     0.000000  0.006998
# 5         0.000330     0.000000  0.002830
# 6         0.001376     0.000000  0.032566
# 7         0.000698     0.000000  0.003101
# 8         0.000640     0.000000  0.000853
# 9         0.001357     0.000000  0.002636
# 10        0.000678     0.000000  0.002753
# 11        0.000194     0.000000  0.001803
# 12        0.001182     0.000000  0.002035
# 13        0.000795     0.000000  0.002094
# 14        0.000058     0.000000  0.001454
# 15        0.000678     0.000000  0.001454
# 16        0.000000     0.000000  0.000678
# 17        0.000233     0.000000  0.000039
# 18        0.000504     0.000000  0.000000
# 19        0.000000     0.000000  0.000019
# 20        0.000019     0.000000  0.000000
# 21        0.000155     0.000000  0.000000
# 22        0.000000     0.000000  0.000174
# 25        0.000155     0.000000  0.000000
# 27        0.000000     0.000000  0.000155
# 999       0.105179     0.783496  0.000000

# %%
#creating a new column named "pdays2" based on the value in "pdays" column 
def function (row):
    if(row['pdays']==999):
        return 0;
    return 1;
data['pdays2']=data.apply(lambda row: function(row),axis=1)
#changing the value 999 in pdays column to  value 30 
def function1 (row):
    if(row['pdays']==999):
        return 30;
    return row['pdays'];
data['pdays']=data.apply(lambda row: function1(row),axis=1)

#changing the type of pdays to int
data['pdays']=data['pdays'].astype(int)
data.head()
# Out:
#        age          job  marital          education  default housing loan  \
# 39075   29       admin.  married  university.degree       no      no   no
# 34855   29   technician   single  university.degree       no      no   no
# 7107    45  blue-collar  married           basic.6y  unknown     yes   no
# 31614   34     services  married  university.degree       no      no   no
# 34878   32       admin.   single        high.school       no      no   no
#
#          contact month day_of_week  ...  pdays  previous     poutcome  \
# 39075   cellular   dec         mon  ...     30         1      failure
# 34855  telephone   may         fri  ...     30         0  nonexistent
# 7107   telephone   may         thu  ...     30         0  nonexistent
# 31614   cellular   may         thu  ...     30         1      failure
# 34878   cellular   may         fri  ...     30         0  nonexistent
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y  \
# 39075         -3.0          92.713          -33.0      0.709       5023.5  no
# 34855         -1.8          92.893          -46.2      1.250       5099.1  no
# 7107           1.1          93.994          -36.4      4.860       5191.0  no
# 31614         -1.8          92.893          -46.2      1.327       5099.1  no
# 34878         -1.8          92.893          -46.2      1.250       5099.1  no
#
#       pdays2
# 39075      0
# 34855      0
# 7107       0
# 31614      0
# 34878      0
#
# [5 rows x 21 columns]

# %% [markdown]
# As we can see from the above table, the majority of the values for 'pdays' are missing. The majority of these
# missing values occur when the 'poutcome' is 'non-existent'. This means that the majority of the values in 'pdays'
# are missing because the customer was never contacted before. To deal with this variable, we removed the numerical variable 'pdays' and replaced it with categorical variables with following categories: pdays,pdays2

# %% [markdown]
# # outlier check

# %% [markdown]
# # Outliers
# Outliers are defined as 1.5 x Q3 value (75th percentile). From the above table, it can be seen that only 'age' and 'campaign' have outliers as max('age') and max('campaign') > 1.5Q3('age') and >1.5Q3('campaign') respectively.

# %%
# Check outlier if any for Numberic column.
data.age.plot(kind='box')
# There are outlier and check max age and age greated than 90
# Out:
# <Axes: >

# %%
print(data.age.max())
data[data['age'] > 80].head(5)
# Out:
# 98
#        age      job   marital          education  default housing loan  \
# 27813   88  retired  divorced           basic.4y       no     yes   no
# 38032   91  retired   married  university.degree       no      no  yes
# 37472   88  retired  divorced           basic.4y       no     yes   no
# 39625   82  retired   married        high.school  unknown     yes   no
# 39466   82  retired  divorced           basic.4y       no     yes  yes
#
#         contact month day_of_week  ...  pdays  previous     poutcome  \
# 27813  cellular   mar         wed  ...     30         0  nonexistent
# 38032  cellular   sep         wed  ...     30         0  nonexistent
# 37472  cellular   aug         thu  ...     30         0  nonexistent
# 39625  cellular   may         mon  ...     30         0  nonexistent
# 39466  cellular   apr         mon  ...     30         0  nonexistent
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# 27813         -1.8          92.843          -50.0      1.663       5099.1
# 38032         -3.4          92.379          -29.8      0.781       5017.5
# 37472         -2.9          92.201          -31.4      0.873       5076.2
# 39625         -1.8          93.876          -40.0      0.682       5008.7
# 39466         -1.8          93.749          -34.6      0.643       5008.7
#
#          y pdays2
# 27813  yes      0
# 38032   no      0
# 37472   no      0
# 39625   no      0
# 39466  yes      0
#
# [5 rows x 21 columns]

# %%
data.age.plot(kind='hist')
# it is bit positively skewed but it is ok and seems no high dependency with Output variable
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.age.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# Create Binning for all numeric fields base on Box plot quantile
def binning(dataframe,featureName):
    print (featureName)
    q1 = dataframe[featureName].quantile(0.25)
    q2 = dataframe[featureName].quantile(0.50)
    q3 = dataframe[featureName].quantile(0.75)
    dataframe.loc[(dataframe[featureName] <= q1), featureName] = 1
    dataframe.loc[(dataframe[featureName] > q1) & (dataframe[featureName] <= q2), featureName] = 2
    dataframe.loc[(dataframe[featureName] > q2) & (dataframe[featureName] <= q3), featureName] = 3
    dataframe.loc[(dataframe[featureName] > q3), featureName] = 4 
    print (q1, q2, q3)

# %%
binning(data,'age')
# Out:
# age
# 31.0 38.0 48.0

# %% [markdown]
# # outliner check for feature campaign

# %%
# let check campaign field now and it is positively skewed..
data.campaign.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.campaign.plot(kind='box')
# lot of exreme values.
# Out:
# <Axes: >

# %%
print(data.campaign.max())
print(data.campaign.mean())
print(data.campaign.median())
print(data.campaign.unique())
print('Y=1 for campaign > 10' , data[(data['campaign'] > 10) & (data['y'] ==1)].age.count())
print('Y=1 for campaign < 10' , data[(data['campaign'] <= 10) & (data['y'] ==1)].age.count())
print('Y=1 for campaign = 1' , data[(data['campaign'] == 1) & (data['y'] ==1)].age.count())
# Out:
# 43
# 2.334670853686904
# 2.0
# [ 3  4  2  1  9  5  6 12  7  8 10 11 19 15 13 14 17 18 25 32 21 16 40 24
#  27 22 23 35 20 43 26 29 33 31 28 34 30 41 39 37]
# Y=1 for campaign > 10 0
# Y=1 for campaign < 10 0
# Y=1 for campaign = 1 0

# %%
data.groupby(['campaign','y']).y.count()
# Out:
# campaign  y
# 1         no     10648
#           yes    12928
# 2         no      6538
#           yes     6808
# 3         no      3401
#           yes     3224
# 4         no      1709
#           yes     1464
# 5         no      1012
#           yes      568
# 6         no       641
#           yes      424
# 7         no       409
#           yes      200
# 8         no       269
#           yes      112
# 9         no       205
#           yes      104
# 10        no       149
#           yes       48
# 11        no       119
#           yes       56
# 12        no        93
#           yes       16
# 13        no        62
#           yes       32
# 14        no        46
#           yes        8
# 15        no        33
# 16        no        38
# 17        no        41
#           yes       16
# 18        no        22
# 19        no        19
# 20        no        20
# 21        no        18
# 22        no        12
# 23        no        11
# 24        no        12
# 25        no         4
# 26        no         7
# 27        no         6
# 28        no         3
# 29        no         7
# 30        no         4
# 31        no         3
# 32        no         3
# 33        no         2
# 34        no         3
# 35        no         4
# 37        no         1
# 39        no         1
# 40        no         2
# 41        no         1
# 43        no         2
# Name: y, dtype: int64

# %%
data['campaign'].describe()
# Out:
# count    51588.000000
# mean         2.334671
# std          2.328928
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         43.000000
# Name: campaign, dtype: float64

# %%
q1 = data['campaign'].quantile(0.25)
q2 = data['campaign'].quantile(0.50)
q3 = data['campaign'].quantile(0.75)

print(q1)
print(q2)
print(q3)

iqr = q3-q1 #Interquartile range

extreme_low_campaign = q1-1.5*iqr
extreme_high_capmaign = q3+1.5*iqr

print (extreme_low_campaign)
print (extreme_high_capmaign)
# Out:
# 1.0
# 2.0
# 3.0
# -2.0
# 6.0

# %%
binning(data,'campaign')
# Out:
# campaign
# 1.0 2.0 3.0

# %%
data.head(5)
# Out:
#        age          job  marital          education  default housing loan  \
# 39075    1       admin.  married  university.degree       no      no   no
# 34855    1   technician   single  university.degree       no      no   no
# 7107     3  blue-collar  married           basic.6y  unknown     yes   no
# 31614    2     services  married  university.degree       no      no   no
# 34878    2       admin.   single        high.school       no      no   no
#
#          contact month day_of_week  ...  pdays  previous     poutcome  \
# 39075   cellular   dec         mon  ...     30         1      failure
# 34855  telephone   may         fri  ...     30         0  nonexistent
# 7107   telephone   may         thu  ...     30         0  nonexistent
# 31614   cellular   may         thu  ...     30         1      failure
# 34878   cellular   may         fri  ...     30         0  nonexistent
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y  \
# 39075         -3.0          92.713          -33.0      0.709       5023.5  no
# 34855         -1.8          92.893          -46.2      1.250       5099.1  no
# 7107           1.1          93.994          -36.4      4.860       5191.0  no
# 31614         -1.8          92.893          -46.2      1.327       5099.1  no
# 34878         -1.8          92.893          -46.2      1.250       5099.1  no
#
#       pdays2
# 39075      0
# 34855      0
# 7107       0
# 31614      0
# 34878      0
#
# [5 rows x 21 columns]

# %% [markdown]
# # Standardizing the data

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'y', 'pdays2'],
#       dtype='object')

# %%
data.head()
# Out:
#        age          job  marital          education  default housing loan  \
# 39075    1       admin.  married  university.degree       no      no   no
# 34855    1   technician   single  university.degree       no      no   no
# 7107     3  blue-collar  married           basic.6y  unknown     yes   no
# 31614    2     services  married  university.degree       no      no   no
# 34878    2       admin.   single        high.school       no      no   no
#
#          contact month day_of_week  ...  pdays  previous     poutcome  \
# 39075   cellular   dec         mon  ...     30         1      failure
# 34855  telephone   may         fri  ...     30         0  nonexistent
# 7107   telephone   may         thu  ...     30         0  nonexistent
# 31614   cellular   may         thu  ...     30         1      failure
# 34878   cellular   may         fri  ...     30         0  nonexistent
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y  \
# 39075         -3.0          92.713          -33.0      0.709       5023.5  no
# 34855         -1.8          92.893          -46.2      1.250       5099.1  no
# 7107           1.1          93.994          -36.4      4.860       5191.0  no
# 31614         -1.8          92.893          -46.2      1.327       5099.1  no
# 34878         -1.8          92.893          -46.2      1.250       5099.1  no
#
#       pdays2
# 39075      0
# 34855      0
# 7107       0
# 31614      0
# 34878      0
#
# [5 rows x 21 columns]

# %%
idx_numeric=[0,10,11,12,14,15,16,17,18]
scaler = MinMaxScaler()
data[data.columns[idx_numeric]] = scaler.fit_transform(data[data.columns[idx_numeric]])

# %% [markdown]
# # Categorical variables can be either Ordinal or Nominal

# %%
data['poutcome'] = data['poutcome'].map({'failure': -1,'nonexistent': 0,'success': 1})
data['default'] = data['default'].map({'yes': -1,'unknown': 0,'no': 1})
data['housing'] = data['housing'].map({'yes': -1,'unknown': 0,'no': 1})
data['loan'] = data['loan'].map({'yes': -1,'unknown': 0,'no': 1})

# %% [markdown]
# # Handling Nominal Variables(One Hot Encoding)

# %% [markdown]
# 'job', 'maritial', 'education', 'contact', 'month', 'day_of_week' are Nominal Variables

# %%
# One hot encoding of nominal varibles
nominal = ['job','marital','education','contact','month','day_of_week']
data_clean = pd.get_dummies(data,columns=nominal)
data_clean['y']=data_clean['y'].map({'yes': 1,'no': 0})
data_clean.head()
# Out:
#             age  default  housing  loan  campaign  pdays  previous  poutcome  \
# 39075  0.000000        1        1     1  0.666667    1.0  0.142857        -1
# 34855  0.000000        1        1     1  1.000000    1.0  0.000000         0
# 7107   0.666667        0       -1     1  0.333333    1.0  0.000000         0
# 31614  0.333333        1        1     1  0.000000    1.0  0.142857        -1
# 34878  0.333333        1        1     1  1.000000    1.0  0.000000         0
#
#        emp.var.rate  cons.price.idx  ...  month_mar  month_may  month_nov  \
# 39075      0.083333        0.199532  ...      False      False      False
# 34855      0.333333        0.269680  ...      False       True      False
# 7107       0.937500        0.698753  ...      False       True      False
# 31614      0.333333        0.269680  ...      False       True      False
# 34878      0.333333        0.269680  ...      False       True      False
#
#        month_oct  month_sep  day_of_week_fri  day_of_week_mon  \
# 39075      False      False            False             True
# 34855      False      False             True            False
# 7107       False      False            False            False
# 31614      False      False            False            False
# 34878      False      False             True            False
#
#        day_of_week_thu  day_of_week_tue  day_of_week_wed
# 39075            False            False            False
# 34855            False            False            False
# 7107              True            False            False
# 31614             True            False            False
# 34878            False            False            False
#
# [5 rows x 56 columns]

# %%
data_clean.columns
# Out:
# Index(['age', 'default', 'housing', 'loan', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'y', 'pdays2', 'job_admin.',
#        'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
#        'job_management', 'job_retired', 'job_self-employed', 'job_services',
#        'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
#        'marital_divorced', 'marital_married', 'marital_single',
#        'marital_unknown', 'education_basic.4y', 'education_basic.6y',
#        'education_basic.9y', 'education_high.school', 'education_illiterate',
#        'education_professional.course', 'education_university.degree',
#        'education_unknown', 'contact_cellular', 'contact_telephone',
#        'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun',
#        'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep',
#        'day_of_week_fri', 'day_of_week_mon', 'day_of_week_thu',
#        'day_of_week_tue', 'day_of_week_wed'],
#       dtype='object')

# %%
data_clean.shape
# Out:
# (51588, 56)

# %%
df_with_dummies=pd.get_dummies(data_clean)

# %%
def dropfeature(df,f):
    """Drops one of the dummy variables."""
    df=df.drop(f,axis=1)
    return df

# %%
features_dropped = ['marital_single','contact_cellular',
                    'education_unknown','job_unknown',
     'marital_single','contact_cellular',
                    'education_unknown']
data_clean = dropfeature(df_with_dummies, features_dropped)

# %% [markdown]
# # Aanalising the data distribution by plotting graphs for numerical fields

# %%
 data_clean.describe()
# Out:
#                 age       default       housing          loan      campaign  \
# count  51588.000000  51588.000000  51588.000000  51588.000000  51588.000000
# mean       0.481165      0.842211     -0.082461      0.687408      0.327718
# std        0.369656      0.364653      0.996565      0.726225      0.366461
# min        0.000000     -1.000000     -1.000000     -1.000000      0.000000
# 25%        0.000000      1.000000     -1.000000      1.000000      0.000000
# 50%        0.333333      1.000000     -1.000000      1.000000      0.333333
# 75%        0.666667      1.000000      1.000000      1.000000      0.666667
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#               pdays      previous      poutcome  emp.var.rate  cons.price.idx  \
# count  51588.000000  51588.000000  51588.000000  51588.000000    51588.000000
# mean       0.910696      0.044465     -0.012348      0.604021        0.498476
# std        0.255672      0.099432      0.465140      0.358692        0.247116
# min        0.000000      0.000000     -1.000000      0.000000        0.000000
# 25%        1.000000      0.000000      0.000000      0.333333        0.269680
# 50%        1.000000      0.000000      0.000000      0.687500        0.484412
# 75%        1.000000      0.000000      0.000000      1.000000        0.698753
# max        1.000000      1.000000      1.000000      1.000000        1.000000
#
#        cons.conf.idx     euribor3m   nr.employed             y        pdays2
# count   51588.000000  51588.000000  51588.000000  51588.000000  51588.000000
# mean        0.442809      0.526825      0.648359      0.504148      0.111324
# std         0.224640      0.428502      0.330163      0.499988      0.314536
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.338912      0.138291      0.425709      0.000000      0.000000
# 50%         0.376569      0.767853      0.859735      1.000000      0.000000
# 75%         0.602510      0.980503      1.000000      1.000000      0.000000
# max         1.000000      1.000000      1.000000      1.000000      1.000000

# %%
data_clean.head()
# Out:
#             age  default  housing  loan  campaign  pdays  previous  poutcome  \
# 39075  0.000000        1        1     1  0.666667    1.0  0.142857        -1
# 34855  0.000000        1        1     1  1.000000    1.0  0.000000         0
# 7107   0.666667        0       -1     1  0.333333    1.0  0.000000         0
# 31614  0.333333        1        1     1  0.000000    1.0  0.142857        -1
# 34878  0.333333        1        1     1  1.000000    1.0  0.000000         0
#
#        emp.var.rate  cons.price.idx  ...  month_mar  month_may  month_nov  \
# 39075      0.083333        0.199532  ...      False      False      False
# 34855      0.333333        0.269680  ...      False       True      False
# 7107       0.937500        0.698753  ...      False       True      False
# 31614      0.333333        0.269680  ...      False       True      False
# 34878      0.333333        0.269680  ...      False       True      False
#
#        month_oct  month_sep  day_of_week_fri  day_of_week_mon  \
# 39075      False      False            False             True
# 34855      False      False             True            False
# 7107       False      False            False            False
# 31614      False      False            False            False
# 34878      False      False             True            False
#
#        day_of_week_thu  day_of_week_tue  day_of_week_wed
# 39075            False            False            False
# 34855            False            False            False
# 7107              True            False            False
# 31614             True            False            False
# 34878            False            False            False
#
# [5 rows x 52 columns]

# %%
data_clean.shape
# Out:
# (51588, 52)

# %%
data_clean.corr()
# Input feature - nr.employed and  euribor3m (.94) and emp.var.rate and nr.employed (.90) 
#and euribor3m and emp.var.rate (.97) are more correlated and we can remove on column.
# And lets Remove columns - euribor3m and emp.var.rate
# Out:
#                                     age   default   housing      loan  \
# age                            1.000000 -0.159097 -0.001322  0.003100
# default                       -0.159097  1.000000 -0.019429 -0.005087
# housing                       -0.001322 -0.019429  1.000000  0.040290
# loan                           0.003100 -0.005087  0.040290  1.000000
# campaign                       0.004681 -0.052518  0.001952 -0.012350
# pdays                         -0.016179 -0.116533  0.007912  0.019385
# previous                       0.014762  0.128664 -0.009639 -0.000027
# poutcome                       0.011068  0.025770 -0.002071 -0.018198
# emp.var.rate                   0.030919 -0.269147  0.047568 -0.013295
# cons.price.idx                 0.018910 -0.169529  0.059608 -0.008933
# cons.conf.idx                  0.102651  0.007123  0.032345  0.020182
# euribor3m                      0.039051 -0.268032  0.050265 -0.009826
# nr.employed                    0.017508 -0.260352  0.035431 -0.011208
# y                             -0.032947  0.174342 -0.012113  0.000101
# pdays2                         0.013838  0.117999 -0.007509 -0.017209
# job_admin.                    -0.107240  0.114042 -0.000732 -0.011485
# job_blue-collar                0.015869 -0.200815  0.028951  0.005010
# job_entrepreneur               0.041854 -0.013014 -0.008624  0.011272
# job_housemaid                  0.092825 -0.027735  0.015640  0.007446
# job_management                 0.075787  0.040568  0.013592  0.005474
# job_retired                    0.354760  0.014107  0.000181 -0.002078
# job_self-employed             -0.011675 -0.000598  0.009147  0.002489
# job_services                  -0.061198 -0.027105 -0.004344 -0.010047
# job_student                   -0.241201  0.053183 -0.018700 -0.013296
# job_technician                -0.051993  0.056619 -0.029008  0.003843
# job_unemployed                -0.010176 -0.002830 -0.014895  0.014484
# marital_divorced               0.181917  0.023029 -0.003883  0.003286
# marital_married                0.343594 -0.135859  0.007997 -0.001321
# marital_unknown               -0.002686  0.007139  0.015546  0.008195
# education_basic.4y             0.261242 -0.154634  0.016597 -0.008566
# education_basic.6y             0.016176 -0.103685  0.008127  0.013980
# education_basic.9y            -0.023610 -0.076409  0.012936 -0.010944
# education_high.school         -0.101765  0.043584  0.001491  0.002827
# education_illiterate           0.020225 -0.014840 -0.018251 -0.008573
# education_professional.course  0.013987  0.041031 -0.033771  0.002717
# education_university.degree   -0.090016  0.147483 -0.000968 -0.000499
# contact_telephone              0.031191 -0.166672  0.076851  0.013430
# month_apr                     -0.000737  0.070566 -0.048556  0.002239
# month_aug                      0.055406  0.003253 -0.024029  0.017094
# month_dec                      0.042394  0.032610 -0.011179 -0.000083
# month_jul                     -0.024798 -0.057701  0.007393 -0.026915
# month_jun                     -0.019974 -0.043552  0.059061  0.005891
# month_mar                     -0.038413  0.068832 -0.013602  0.015185
# month_may                     -0.033938 -0.104417  0.017866 -0.008631
# month_nov                      0.032674  0.061367 -0.026064 -0.003285
# month_oct                      0.017616  0.070678  0.014022  0.017894
# month_sep                      0.005111  0.072096  0.002064 -0.001824
# day_of_week_fri                0.006108 -0.019440  0.013733  0.000908
# day_of_week_mon                0.030581 -0.008828 -0.010372 -0.004767
# day_of_week_thu               -0.024087  0.010356 -0.015512  0.003704
# day_of_week_tue                0.013874 -0.001139  0.004912 -0.001393
# day_of_week_wed               -0.025249  0.018116  0.007973  0.001412
#
#                                campaign     pdays  previous  poutcome  \
# age                            0.004681 -0.016179  0.014762  0.011068
# default                       -0.052518 -0.116533  0.128664  0.025770
# housing                        0.001952  0.007912 -0.009639 -0.002071
# loan                          -0.012350  0.019385 -0.000027 -0.018198
# campaign                       1.000000  0.087789 -0.089996 -0.019361
# pdays                          0.087789  1.000000 -0.700447 -0.659579
# previous                      -0.089996 -0.700447  1.000000  0.075520
# poutcome                      -0.019361 -0.659579  0.075520  1.000000
# emp.var.rate                   0.184304  0.331613 -0.379976 -0.008916
# cons.price.idx                 0.121563  0.040687 -0.057011  0.114572
# cons.conf.idx                 -0.034240 -0.158459  0.071777  0.134996
# euribor3m                      0.166938  0.380179 -0.445720 -0.036954
# nr.employed                    0.169953  0.464418 -0.519581 -0.113410
# y                             -0.111788 -0.302358  0.254500  0.160798
# pdays2                        -0.086793 -0.986892  0.706013  0.643922
# job_admin.                    -0.001394 -0.037200  0.024231  0.026918
# job_blue-collar                0.015190  0.108956 -0.101213 -0.052822
# job_entrepreneur              -0.001159  0.037910 -0.033220 -0.016541
# job_housemaid                  0.003439 -0.014767  0.008370  0.026227
# job_management                -0.002996 -0.007100  0.015904 -0.004008
# job_retired                   -0.026843 -0.092019  0.092077  0.042941
# job_self-employed              0.010102  0.024411 -0.029620 -0.012417
# job_services                   0.019149  0.037116 -0.029880 -0.028341
# job_student                   -0.031576 -0.095798  0.108124  0.024774
# job_technician                 0.004195  0.009808 -0.006435 -0.005100
# job_unemployed                -0.004031 -0.035013  0.010157  0.032829
# marital_divorced               0.015558  0.002507 -0.001773 -0.000975
# marital_married                0.009489  0.035467 -0.038145 -0.013816
# marital_unknown                0.002673 -0.006484  0.011066  0.002119
# education_basic.4y            -0.002883 -0.009512 -0.006690  0.024324
# education_basic.6y             0.016553  0.037914 -0.039456 -0.018321
# education_basic.9y             0.010528  0.083703 -0.076272 -0.043454
# education_high.school         -0.002008  0.019652 -0.005585 -0.033649
# education_illiterate          -0.004575 -0.010787 -0.001074  0.012378
# education_professional.course -0.002066 -0.013299  0.006942  0.010734
# education_university.degree   -0.004526 -0.061803  0.053341  0.044015
# contact_telephone              0.088219  0.152674 -0.206248  0.023648
# month_apr                     -0.076062  0.026512 -0.004714 -0.051517
# month_aug                      0.035682 -0.011707 -0.012066  0.047954
# month_dec                     -0.002808 -0.071976  0.053680  0.034502
# month_jul                      0.100945  0.077106 -0.103172  0.023648
# month_jun                      0.041615  0.023981 -0.058243  0.026023
# month_mar                     -0.033663 -0.081912  0.069092  0.047210
# month_may                      0.033967  0.109855 -0.061921 -0.102090
# month_nov                     -0.082197 -0.027498  0.064608 -0.042283
# month_oct                     -0.099385 -0.133870  0.125413  0.049451
# month_sep                     -0.037290 -0.175936  0.159271  0.089394
# day_of_week_fri                0.053995  0.011980 -0.007175 -0.016053
# day_of_week_mon                0.060507  0.009906 -0.008406  0.000790
# day_of_week_thu               -0.043922  0.002568  0.001133 -0.002185
# day_of_week_tue               -0.035848 -0.013781  0.010009  0.006060
# day_of_week_wed               -0.031424 -0.010348  0.004146  0.011029
#
#                                emp.var.rate  cons.price.idx  ...  month_mar  \
# age                                0.030919        0.018910  ...  -0.038413
# default                           -0.269147       -0.169529  ...   0.068832
# housing                            0.047568        0.059608  ...  -0.013602
# loan                              -0.013295       -0.008933  ...   0.015185
# campaign                           0.184304        0.121563  ...  -0.033663
# pdays                              0.331613        0.040687  ...  -0.081912
# previous                          -0.379976       -0.057011  ...   0.069092
# poutcome                          -0.008916        0.114572  ...   0.047210
# emp.var.rate                       1.000000        0.716164  ...  -0.142870
# cons.price.idx                     0.716164        1.000000  ...  -0.105663
# cons.conf.idx                     -0.068815       -0.169471  ...  -0.056413
# euribor3m                          0.958018        0.565191  ...  -0.184766
# nr.employed                        0.867831        0.342814  ...  -0.183536
# y                                 -0.433240       -0.195772  ...   0.145116
# pdays2                            -0.332230       -0.033207  ...   0.086419
# job_admin.                        -0.050294       -0.044901  ...   0.020862
# job_blue-collar                    0.142491        0.094519  ...  -0.040556
# job_entrepreneur                   0.028418        0.007689  ...  -0.028764
# job_housemaid                      0.021436        0.026475  ...  -0.011648
# job_management                    -0.011405       -0.026560  ...  -0.017339
# job_retired                       -0.160624       -0.068873  ...   0.034469
# job_self-employed                  0.012215       -0.005977  ...   0.005385
# job_services                       0.056126        0.046127  ...  -0.029120
# job_student                       -0.153157       -0.059521  ...   0.061558
# job_technician                     0.045962        0.000117  ...   0.013843
# job_unemployed                    -0.034083       -0.005272  ...   0.002764
# marital_divorced                   0.027778        0.031776  ...   0.002521
# marital_married                    0.096130        0.041144  ...  -0.066954
# marital_unknown                   -0.009966       -0.017600  ...   0.010810
# education_basic.4y                 0.016876        0.032257  ...  -0.005605
# education_basic.6y                 0.053006        0.033083  ...  -0.020814
# education_basic.9y                 0.083750        0.044161  ...  -0.027235
# education_high.school              0.006662        0.018513  ...  -0.021278
# education_illiterate              -0.010707       -0.020765  ...  -0.004717
# education_professional.course      0.011189        0.010206  ...   0.013072
# education_university.degree       -0.091416       -0.092354  ...   0.029087
# contact_telephone                  0.423897        0.485214  ...  -0.080682
# month_apr                         -0.232469       -0.156808  ...  -0.058318
# month_aug                          0.135313       -0.173731  ...  -0.078090
# month_dec                         -0.147487       -0.126757  ...  -0.019868
# month_jul                          0.314367        0.272934  ...  -0.082916
# month_jun                          0.084552        0.316553  ...  -0.072115
# month_mar                         -0.142870       -0.105663  ...   1.000000
# month_may                          0.021320       -0.017368  ...  -0.113836
# month_nov                         -0.070048       -0.137411  ...  -0.061512
# month_oct                         -0.219587       -0.080378  ...  -0.039814
# month_sep                         -0.167067       -0.020259  ...  -0.034077
# day_of_week_fri                   -0.006567       -0.010674  ...  -0.012033
# day_of_week_mon                    0.005030        0.011871  ...   0.020081
# day_of_week_thu                   -0.013159       -0.004324  ...  -0.029520
# day_of_week_tue                   -0.017998       -0.021168  ...   0.051158
# day_of_week_wed                    0.032894        0.024189  ...  -0.028813
#
#                                month_may  month_nov  month_oct  month_sep  \
# age                            -0.033938   0.032674   0.017616   0.005111
# default                        -0.104417   0.061367   0.070678   0.072096
# housing                         0.017866  -0.026064   0.014022   0.002064
# loan                           -0.008631  -0.003285   0.017894  -0.001824
# campaign                        0.033967  -0.082197  -0.099385  -0.037290
# pdays                           0.109855  -0.027498  -0.133870  -0.175936
# previous                       -0.061921   0.064608   0.125413   0.159271
# poutcome                       -0.102090  -0.042283   0.049451   0.089394
# emp.var.rate                    0.021320  -0.070048  -0.219587  -0.167067
# cons.price.idx                 -0.017368  -0.137411  -0.080378  -0.020259
# cons.conf.idx                  -0.118286  -0.000427   0.196367   0.203185
# euribor3m                      -0.007866   0.034310  -0.176906  -0.201921
# nr.employed                     0.015887   0.016877  -0.263367  -0.305238
# y                              -0.188426  -0.018394   0.152933   0.129815
# pdays2                         -0.111087   0.020890   0.136404   0.174534
# job_admin.                     -0.066153   0.003946   0.021958   0.030917
# job_blue-collar                 0.166606  -0.041955  -0.067199  -0.075322
# job_entrepreneur                0.006780   0.040097  -0.020118  -0.003661
# job_housemaid                  -0.019935  -0.001344   0.007303  -0.012225
# job_management                 -0.016664   0.079436   0.003926   0.001276
# job_retired                    -0.089838  -0.000944   0.088348   0.047326
# job_self-employed              -0.010093   0.014218  -0.012443  -0.002651
# job_services                    0.073648  -0.030365  -0.026267  -0.019706
# job_student                    -0.036877  -0.017987   0.031671   0.040561
# job_technician                 -0.045081  -0.007476  -0.006095   0.005301
# job_unemployed                 -0.017815   0.010302   0.009048   0.020314
# marital_divorced               -0.007681   0.035804  -0.025062  -0.016021
# marital_married                 0.037527   0.005138  -0.000488  -0.005680
# marital_unknown                 0.002165  -0.006930   0.010282  -0.007972
# education_basic.4y              0.019140  -0.028767   0.010855  -0.010322
# education_basic.6y              0.079716  -0.023853  -0.020928  -0.022271
# education_basic.9y              0.111348  -0.024757  -0.053222  -0.050928
# education_high.school           0.037329  -0.017416   0.024918  -0.012942
# education_illiterate           -0.011455   0.015748  -0.005239  -0.004484
# education_professional.course  -0.030167   0.010964   0.001256   0.027751
# education_university.degree    -0.128984   0.061168   0.019520   0.034044
# contact_telephone               0.309454  -0.118608  -0.035138  -0.071452
# month_apr                      -0.185226  -0.100087  -0.064783  -0.055448
# month_aug                      -0.248023  -0.134020  -0.086747  -0.074247
# month_dec                      -0.063104  -0.034099  -0.022071  -0.018891
# month_jul                      -0.263352  -0.142303  -0.092108  -0.078836
# month_jun                      -0.229047  -0.123766  -0.080110  -0.068566
# month_mar                      -0.113836  -0.061512  -0.039814  -0.034077
# month_may                       1.000000  -0.195368  -0.126455  -0.108233
# month_nov                      -0.195368   1.000000  -0.068330  -0.058484
# month_oct                      -0.126455  -0.068330   1.000000  -0.037855
# month_sep                      -0.108233  -0.058484  -0.037855   1.000000
# day_of_week_fri                 0.034334   0.007526   0.017569   0.000793
# day_of_week_mon                -0.002520  -0.015783  -0.032306  -0.025924
# day_of_week_thu                -0.041191  -0.001300  -0.001790  -0.003967
# day_of_week_tue                -0.004041   0.007089   0.011067   0.006651
# day_of_week_wed                 0.015525   0.002568   0.005691   0.022329
#
#                                day_of_week_fri  day_of_week_mon  \
# age                                   0.006108         0.030581
# default                              -0.019440        -0.008828
# housing                               0.013733        -0.010372
# loan                                  0.000908        -0.004767
# campaign                              0.053995         0.060507
# pdays                                 0.011980         0.009906
# previous                             -0.007175        -0.008406
# poutcome                             -0.016053         0.000790
# emp.var.rate                         -0.006567         0.005030
# cons.price.idx                       -0.010674         0.011871
# cons.conf.idx                         0.027332        -0.057085
# euribor3m                             0.002082        -0.000008
# nr.employed                           0.004925         0.008606
# y                                    -0.015019        -0.030877
# pdays2                               -0.012029        -0.009261
# job_admin.                           -0.000919         0.006264
# job_blue-collar                       0.003774        -0.008635
# job_entrepreneur                      0.010240        -0.002390
# job_housemaid                        -0.004849        -0.000575
# job_management                       -0.015922         0.020658
# job_retired                           0.001640        -0.004537
# job_self-employed                     0.001122        -0.003032
# job_services                         -0.003797         0.004937
# job_student                           0.003716        -0.013981
# job_technician                        0.005751        -0.001247
# job_unemployed                       -0.001837        -0.003425
# marital_divorced                     -0.001315         0.005956
# marital_married                      -0.009368         0.019019
# marital_unknown                       0.004666         0.008025
# education_basic.4y                   -0.010895         0.004276
# education_basic.6y                   -0.001190        -0.015493
# education_basic.9y                    0.009201         0.000980
# education_high.school                 0.007840        -0.003695
# education_illiterate                 -0.007939        -0.012280
# education_professional.course        -0.001696        -0.008940
# education_university.degree          -0.010271         0.014459
# contact_telephone                     0.038222        -0.011031
# month_apr                            -0.019027         0.003830
# month_aug                             0.002650        -0.015702
# month_dec                            -0.025357         0.027380
# month_jul                            -0.039656         0.005187
# month_jun                             0.008334         0.038528
# month_mar                            -0.012033         0.020081
# month_may                             0.034334        -0.002520
# month_nov                             0.007526        -0.015783
# month_oct                             0.017569        -0.032306
# month_sep                             0.000793        -0.025924
# day_of_week_fri                       1.000000        -0.236144
# day_of_week_mon                      -0.236144         1.000000
# day_of_week_thu                      -0.252384        -0.259673
# day_of_week_tue                      -0.239211        -0.246120
# day_of_week_wed                      -0.240328        -0.247269
#
#                                day_of_week_thu  day_of_week_tue  \
# age                                  -0.024087         0.013874
# default                               0.010356        -0.001139
# housing                              -0.015512         0.004912
# loan                                  0.003704        -0.001393
# campaign                             -0.043922        -0.035848
# pdays                                 0.002568        -0.013781
# previous                              0.001133         0.010009
# poutcome                             -0.002185         0.006060
# emp.var.rate                         -0.013159        -0.017998
# cons.price.idx                       -0.004324        -0.021168
# cons.conf.idx                        -0.046866         0.062836
# euribor3m                            -0.025770        -0.007158
# nr.employed                          -0.013811        -0.019077
# y                                     0.026138         0.011039
# pdays2                               -0.001287         0.013865
# job_admin.                            0.010772        -0.013991
# job_blue-collar                      -0.005005        -0.007569
# job_entrepreneur                      0.005208         0.000308
# job_housemaid                        -0.007905         0.015897
# job_management                       -0.009907         0.004753
# job_retired                          -0.028686         0.021032
# job_self-employed                     0.017279        -0.011919
# job_services                         -0.004785         0.009696
# job_student                           0.005213        -0.002094
# job_technician                        0.012382         0.002488
# job_unemployed                        0.004300        -0.007791
# marital_divorced                     -0.007026         0.002820
# marital_married                      -0.009616        -0.002589
# marital_unknown                       0.008570        -0.013337
# education_basic.4y                   -0.021942         0.032142
# education_basic.6y                    0.000367         0.009062
# education_basic.9y                   -0.006394        -0.014646
# education_high.school                -0.014452        -0.012282
# education_illiterate                  0.022747         0.007040
# education_professional.course         0.007348         0.018152
# education_university.degree           0.024851        -0.013259
# contact_telephone                    -0.036012        -0.005533
# month_apr                             0.116909        -0.054344
# month_aug                            -0.001003         0.001388
# month_dec                            -0.004116        -0.008015
# month_jul                             0.010905         0.012939
# month_jun                            -0.033363        -0.006493
# month_mar                            -0.029520         0.051158
# month_may                            -0.041191        -0.004041
# month_nov                            -0.001300         0.007089
# month_oct                            -0.001790         0.011067
# month_sep                            -0.003967         0.006651
# day_of_week_fri                      -0.252384        -0.239211
# day_of_week_mon                      -0.259673        -0.246120
# day_of_week_thu                       1.000000        -0.263046
# day_of_week_tue                      -0.263046         1.000000
# day_of_week_wed                      -0.264274        -0.250480
#
#                                day_of_week_wed
# age                                  -0.025249
# default                               0.018116
# housing                               0.007973
# loan                                  0.001412
# campaign                             -0.031424
# pdays                                -0.010348
# previous                              0.004146
# poutcome                              0.011029
# emp.var.rate                          0.032894
# cons.price.idx                        0.024189
# cons.conf.idx                         0.015471
# euribor3m                             0.031637
# nr.employed                           0.019930
# y                                     0.007253
# pdays2                                0.008356
# job_admin.                           -0.002436
# job_blue-collar                       0.017572
# job_entrepreneur                     -0.013256
# job_housemaid                        -0.002436
# job_management                        0.000493
# job_retired                           0.011438
# job_self-employed                    -0.003983
# job_services                         -0.005940
# job_student                           0.006945
# job_technician                       -0.019580
# job_unemployed                        0.008520
# marital_divorced                     -0.000198
# marital_married                       0.002764
# marital_unknown                      -0.007994
# education_basic.4y                   -0.003116
# education_basic.6y                    0.007071
# education_basic.9y                    0.011269
# education_high.school                 0.023152
# education_illiterate                 -0.010555
# education_professional.course        -0.015168
# education_university.degree          -0.016667
# contact_telephone                     0.016325
# month_apr                            -0.051386
# month_aug                             0.012608
# month_dec                             0.009788
# month_jul                             0.009298
# month_jun                            -0.005422
# month_mar                            -0.028813
# month_may                             0.015525
# month_nov                             0.002568
# month_oct                             0.005691
# month_sep                             0.022329
# day_of_week_fri                      -0.240328
# day_of_week_mon                      -0.247269
# day_of_week_thu                      -0.264274
# day_of_week_tue                      -0.250480
# day_of_week_wed                       1.000000
#
# [52 rows x 52 columns]

# %%
def drawheatmap(df):
    '''Builds the heat map for the given data'''
    f, ax = plt.subplots(figsize=(15, 15))
    sns.heatmap(df.corr(method='spearman'), annot=False, cmap='coolwarm')

# %% [markdown]
# Inferences: From the above heat map we can see that 'y' (our target variable) has good correlation with 'previous', 'emp.var.rate', 'euribor3m', 'nr.employed', 'pdays_missing', 'poutcome_success' , 'poutcome_nonexistent'and 'pdays_bet_5_15'. We expect to see these independent variables as significant while building the models.

# %%
drawheatmap(data_clean)

# %% [markdown]
# # Standardizing the test data

# %%
data_1= pd.concat([X_test, y_test], axis=1)

# %%
data_1.shape
# Out:
# (12357, 20)

# %%
data_1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# As we seen in train data the majority of the values for 'pdays' are missing. The majority of these missing values occur when the 'poutcome' is 'non-existent'. This means that the majority of the values in 'pdays' are missing because the customer was never contacted before. To deal with this variable, we removed the numerical variable 'pdays' and replaced it with categorical variables with following categories:'pdays' and 'pdays2'

# %% [markdown]
# # Balancing y out

# %%
sns.countplot(x='y',data=data_1)
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %% [markdown]
# We can see that the data is very skewed, so we duplicate the tuples corresponding to 'yes'

# %%
d1=data_1.copy()
d2=d1[d1.y=='yes']
d1=pd.concat([d1, d2])
d1=pd.concat([d1, d2])
d1=pd.concat([d1, d2])
d1=pd.concat([d1, d2])
d1=pd.concat([d1, d2])
d1=pd.concat([d1, d2])
d1=pd.concat([d1, d2])
data_1=d1

# %%
sns.countplot(x='y',data=data_1)
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %%
#creating a new column named "pdays2" based on the value in "pdays" column 
def function (row):
    if(row['pdays']==999):
        return 0;
    return 1;
data_1['pdays2']=data_1.apply(lambda row: function(row),axis=1)
#changing the value 999 in pdays column to  value 30 
def function1 (row):
    if(row['pdays']==999):
        return 30;
    return row['pdays'];
data_1['pdays']=data_1.apply(lambda row: function1(row),axis=1)

#changing the type of pdays to int
data_1['pdays']=data_1['pdays'].astype(int)
data_1.head()
# Out:
#        age          job  marital    education  default housing loan  \
# 32884   57   technician  married  high.school       no      no  yes
# 3169    55      unknown  married      unknown  unknown     yes   no
# 32206   33  blue-collar  married     basic.9y       no      no   no
# 9403    36       admin.  married  high.school       no      no   no
# 14020   27    housemaid  married  high.school       no     yes   no
#
#          contact month day_of_week  ...  pdays  previous     poutcome  \
# 32884   cellular   may         mon  ...     30         1      failure
# 3169   telephone   may         thu  ...     30         0  nonexistent
# 32206   cellular   may         fri  ...     30         1      failure
# 9403   telephone   jun         fri  ...     30         0  nonexistent
# 14020   cellular   jul         fri  ...     30         0  nonexistent
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y  \
# 32884         -1.8          92.893          -46.2      1.299       5099.1  no
# 3169           1.1          93.994          -36.4      4.860       5191.0  no
# 32206         -1.8          92.893          -46.2      1.313       5099.1  no
# 9403           1.4          94.465          -41.8      4.967       5228.1  no
# 14020          1.4          93.918          -42.7      4.963       5228.1  no
#
#       pdays2
# 32884      0
# 3169       0
# 32206      0
# 9403       0
# 14020      0
#
# [5 rows x 21 columns]

# %%
data_1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'y', 'pdays2'],
#       dtype='object')

# %%
idx_numeric=[0,10,11,12,14,15,16,17,18]
scaler = MinMaxScaler()
data_1[data_1.columns[idx_numeric]] = scaler.fit_transform(data_1[data_1.columns[idx_numeric]])

# %%
data_1.head()
# Out:
#             age          job  marital    education  default housing loan  \
# 32884  0.519481   technician  married  high.school       no      no  yes
# 3169   0.493506      unknown  married      unknown  unknown     yes   no
# 32206  0.207792  blue-collar  married     basic.9y       no      no   no
# 9403   0.246753       admin.  married  high.school       no      no   no
# 14020  0.129870    housemaid  married  high.school       no     yes   no
#
#          contact month day_of_week  ...  pdays  previous     poutcome  \
# 32884   cellular   may         mon  ...    1.0  0.166667      failure
# 3169   telephone   may         thu  ...    1.0  0.000000  nonexistent
# 32206   cellular   may         fri  ...    1.0  0.166667      failure
# 9403   telephone   jun         fri  ...    1.0  0.000000  nonexistent
# 14020   cellular   jul         fri  ...    1.0  0.000000  nonexistent
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y  \
# 32884     0.333333        0.269680       0.192469   0.150759     0.512287  no
# 3169      0.937500        0.698753       0.602510   0.958059     0.859735  no
# 32206     0.333333        0.269680       0.192469   0.153933     0.512287  no
# 9403      1.000000        0.882307       0.376569   0.982317     1.000000  no
# 14020     1.000000        0.669135       0.338912   0.981410     1.000000  no
#
#       pdays2
# 32884      0
# 3169       0
# 32206      0
# 9403       0
# 14020      0
#
# [5 rows x 21 columns]

# %% [markdown]
# #Categorical variables can be either Ordinal or Nominal

# %%
data_1['poutcome'] = data_1['poutcome'].map({'failure': -1,'nonexistent': 0,'success': 1})
data_1['default'] = data_1['default'].map({'yes': -1,'unknown': 0,'no': 1})
data_1['housing'] = data_1['housing'].map({'yes': -1,'unknown': 0,'no': 1})
data_1['loan'] = data_1['loan'].map({'yes': -1,'unknown': 0,'no': 1})

# %%
data_1.head()
# Out:
#             age          job  marital    education  default  housing  loan  \
# 32884  0.519481   technician  married  high.school        1        1    -1
# 3169   0.493506      unknown  married      unknown        0       -1     1
# 32206  0.207792  blue-collar  married     basic.9y        1        1     1
# 9403   0.246753       admin.  married  high.school        1        1     1
# 14020  0.129870    housemaid  married  high.school        1       -1     1
#
#          contact month day_of_week  ...  pdays  previous  poutcome  \
# 32884   cellular   may         mon  ...    1.0  0.166667        -1
# 3169   telephone   may         thu  ...    1.0  0.000000         0
# 32206   cellular   may         fri  ...    1.0  0.166667        -1
# 9403   telephone   jun         fri  ...    1.0  0.000000         0
# 14020   cellular   jul         fri  ...    1.0  0.000000         0
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# 32884      0.333333        0.269680       0.192469   0.150759     0.512287
# 3169       0.937500        0.698753       0.602510   0.958059     0.859735
# 32206      0.333333        0.269680       0.192469   0.153933     0.512287
# 9403       1.000000        0.882307       0.376569   0.982317     1.000000
# 14020      1.000000        0.669135       0.338912   0.981410     1.000000
#
#         y pdays2
# 32884  no      0
# 3169   no      0
# 32206  no      0
# 9403   no      0
# 14020  no      0
#
# [5 rows x 21 columns]

# %%
data_1.shape
# Out:
# (22080, 21)

# %% [markdown]
# #Handling Nominal Variables(One Hot Encoding)

# %% [markdown]
# 'job', 'maritial', 'education', 'contact', 'month', 'day_of_week' are Nominal Variables

# %%
# One hot encoding of nominal varibles
nominal = ['job','marital','education','contact','month','day_of_week']
data_clean_1 = pd.get_dummies(data_1,columns=nominal)
data_clean_1['y']=data_clean_1['y'].map({'yes': 1,'no': 0})
data_clean_1.head()
# Out:
#             age  default  housing  loan  campaign  pdays  previous  poutcome  \
# 32884  0.519481        1        1    -1  0.000000    1.0  0.166667        -1
# 3169   0.493506        0       -1     1  0.018182    1.0  0.000000         0
# 32206  0.207792        1        1     1  0.000000    1.0  0.166667        -1
# 9403   0.246753        1        1     1  0.054545    1.0  0.000000         0
# 14020  0.129870        1       -1     1  0.018182    1.0  0.000000         0
#
#        emp.var.rate  cons.price.idx  ...  month_mar  month_may  month_nov  \
# 32884      0.333333        0.269680  ...      False       True      False
# 3169       0.937500        0.698753  ...      False       True      False
# 32206      0.333333        0.269680  ...      False       True      False
# 9403       1.000000        0.882307  ...      False      False      False
# 14020      1.000000        0.669135  ...      False      False      False
#
#        month_oct  month_sep  day_of_week_fri  day_of_week_mon  \
# 32884      False      False            False             True
# 3169       False      False            False            False
# 32206      False      False             True            False
# 9403       False      False             True            False
# 14020      False      False             True            False
#
#        day_of_week_thu  day_of_week_tue  day_of_week_wed
# 32884            False            False            False
# 3169              True            False            False
# 32206            False            False            False
# 9403             False            False            False
# 14020            False            False            False
#
# [5 rows x 56 columns]

# %%
data_clean_1.shape
# Out:
# (22080, 56)

# %%
df_with_dummies=pd.get_dummies(data_clean_1)

# %%
def dropfeature(df,f):
    """Drops one of the dummy variables."""
    df=df.drop(f,axis=1)
    return df

# %%
features_dropped = ['marital_single','contact_cellular',
                    'education_unknown','job_unknown',
     'marital_single','contact_cellular',
                    'education_unknown']
data_clean_1 = dropfeature(df_with_dummies, features_dropped)

# %%
data_clean_1.shape
# Out:
# (22080, 52)

# %%
data_clean.shape
# Out:
# (51588, 52)

# %%
data_clean_1.columns
# Out:
# Index(['age', 'default', 'housing', 'loan', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'y', 'pdays2', 'job_admin.',
#        'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
#        'job_management', 'job_retired', 'job_self-employed', 'job_services',
#        'job_student', 'job_technician', 'job_unemployed', 'marital_divorced',
#        'marital_married', 'marital_unknown', 'education_basic.4y',
#        'education_basic.6y', 'education_basic.9y', 'education_high.school',
#        'education_illiterate', 'education_professional.course',
#        'education_university.degree', 'contact_telephone', 'month_apr',
#        'month_aug', 'month_dec', 'month_jul', 'month_jun', 'month_mar',
#        'month_may', 'month_nov', 'month_oct', 'month_sep', 'day_of_week_fri',
#        'day_of_week_mon', 'day_of_week_thu', 'day_of_week_tue',
#        'day_of_week_wed'],
#       dtype='object')

# %%
data_clean.columns
# Out:
# Index(['age', 'default', 'housing', 'loan', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'y', 'pdays2', 'job_admin.',
#        'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
#        'job_management', 'job_retired', 'job_self-employed', 'job_services',
#        'job_student', 'job_technician', 'job_unemployed', 'marital_divorced',
#        'marital_married', 'marital_unknown', 'education_basic.4y',
#        'education_basic.6y', 'education_basic.9y', 'education_high.school',
#        'education_illiterate', 'education_professional.course',
#        'education_university.degree', 'contact_telephone', 'month_apr',
#        'month_aug', 'month_dec', 'month_jul', 'month_jun', 'month_mar',
#        'month_may', 'month_nov', 'month_oct', 'month_sep', 'day_of_week_fri',
#        'day_of_week_mon', 'day_of_week_thu', 'day_of_week_tue',
#        'day_of_week_wed'],
#       dtype='object')

# %% [markdown]
# # Create Model

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures
import numpy as np

# %%
data_clean.shape
# Out:
# (51588, 52)

# %%
data_clean_1.shape
# Out:
# (22080, 52)

# %%
# Saperating features and result vectors
y_test=data_clean_1[['y']]
X_test = data_clean_1.drop(['y'], axis=1)

#y = data['y'].values

# %%
# Saperating features and result vectors
y_train=data_clean[['y']]
X_train = data_clean.drop(['y'], axis=1)

#y = data['y'].values

# %%
def Convert_Model(X_train,y_train,X_test,y_test,classifier):
     from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix
     classifier.fit(X_train,y_train) 
     print(classifier.score(X_test,y_test)) 
     print(confusion_matrix(y_test,classifier.predict(X_test)))
     print(accuracy_score(y_test,classifier.predict(X_test)))
     print(precision_score(y_test,classifier.predict(X_test)))
     print(recall_score(y_test,classifier.predict(X_test)))
     f1 = 2 * precision_score(y_test,classifier.predict(X_test)) * recall_score(y_test,classifier.predict(X_test)) / (precision_score(y_test,classifier.predict(X_test)) + recall_score(y_test,classifier.predict(X_test)))
     print("f1 score", f1)
     return classifier

# %%
X_train.shape
# Out:
# (51588, 51)

# %%
X_test.shape
# Out:
# (22080, 51)

# %%
# inport Dummy Classifier for creating Base Model
from sklearn.dummy import DummyClassifier
classifier = DummyClassifier(strategy='most_frequent',random_state=0)
finalModel = Convert_Model(X_train,y_train,X_test,y_test,classifier)
# Out:
# 0.5032608695652174
# [[    0 10968]
#  [    0 11112]]
# 0.5032608695652174
# 0.5032608695652174
# 1.0
# f1 score 0.6695589298626176

# %% [markdown]
# # LogisticRegression

# %%
# Diagnostic: Check X_train and X_test before scaling
print("=== DIAGNOSTIC: X_train and X_test comparison ===")
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"X_train type: {type(X_train)}")
print(f"X_test type: {type(X_test)}")

if hasattr(X_train, 'columns') and hasattr(X_test, 'columns'):
    print(f"\nX_train columns ({len(X_train.columns)}): {list(X_train.columns)}")
    print(f"\nX_test columns ({len(X_test.columns)}): {list(X_test.columns)}")
    
    # Find differences
    train_cols = set(X_train.columns)
    test_cols = set(X_test.columns)
    only_in_test = test_cols - train_cols
    only_in_train = train_cols - test_cols
    
    if only_in_test:
        print(f"\nColumns ONLY in X_test: {list(only_in_test)}")
    if only_in_train:
        print(f"\nColumns ONLY in X_train: {list(only_in_train)}")
        
    if not only_in_test and not only_in_train:
        print("\nAll columns match between X_train and X_test")
else:
    print("\nX_train or X_test doesn't have column information (already numpy arrays)")
# Out:
# === DIAGNOSTIC: X_train and X_test comparison ===
# X_train shape: (51588, 51)
# X_test shape: (22080, 51)
# X_train type: <class 'pandas.core.frame.DataFrame'>
# X_test type: <class 'pandas.core.frame.DataFrame'>
#
# X_train columns (51): ['age', 'default', 'housing', 'loan', 'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'pdays2', 'job_admin.', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid', 'job_management', 'job_retired', 'job_self-employed', 'job_services', 'job_student', 'job_technician', 'job_unemployed', 'marital_divorced', 'marital_married', 'marital_unknown', 'education_basic.4y', 'education_basic.6y', 'education_basic.9y', 'education_high.school', 'education_illiterate', 'education_professional.course', 'education_university.degree', 'contact_telephone', 'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun', 'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep', 'day_of_week_fri', 'day_of_week_mon', 'day_of_week_thu', 'day_of_week_tue', 'day_of_week_wed']
#
# X_test columns (51): ['age', 'default', 'housing', 'loan', 'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'pdays2', 'job_admin.', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid', 'job_management', 'job_retired', 'job_self-employed', 'job_services', 'job_student', 'job_technician', 'job_unemployed', 'marital_divorced', 'marital_married', 'marital_unknown', 'education_basic.4y', 'education_basic.6y', 'education_basic.9y', 'education_high.school', 'education_illiterate', 'education_professional.course', 'education_university.degree', 'contact_telephone', 'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun', 'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep', 'day_of_week_fri', 'day_of_week_mon', 'day_of_week_thu', 'day_of_week_tue', 'day_of_week_wed']
#
# All columns match between X_train and X_test

# %%
# Check what columns are in X_test (DataFrame)
print("X_test columns:")
print(list(X_test.columns))
print(f"\nTotal columns in X_test: {len(X_test.columns)}")

# Let's also check if there are any obvious suspects for the extra column
extra_columns = [col for col in X_test.columns if 'pdays' in col.lower()]
print(f"\nColumns containing 'pdays': {extra_columns}")
# Out:
# X_test columns:
# ['age', 'default', 'housing', 'loan', 'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'pdays2', 'job_admin.', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid', 'job_management', 'job_retired', 'job_self-employed', 'job_services', 'job_student', 'job_technician', 'job_unemployed', 'marital_divorced', 'marital_married', 'marital_unknown', 'education_basic.4y', 'education_basic.6y', 'education_basic.9y', 'education_high.school', 'education_illiterate', 'education_professional.course', 'education_university.degree', 'contact_telephone', 'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun', 'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep', 'day_of_week_fri', 'day_of_week_mon', 'day_of_week_thu', 'day_of_week_tue', 'day_of_week_wed']
#
# Total columns in X_test: 51
#
# Columns containing 'pdays': ['pdays', 'pdays2']

# %%
# Fix the feature mismatch by removing pdays2 from X_test
print("Before fixing:")
print(f"X_test shape: {X_test.shape}")
print(f"Columns with 'pdays': {[col for col in X_test.columns if 'pdays' in col.lower()]}")

# Remove pdays2 column from X_test to match X_train
if 'pdays2' in X_test.columns:
    X_test = X_test.drop('pdays2', axis=1)
    print(f"\nAfter removing 'pdays2':")
    print(f"X_test shape: {X_test.shape}")
    print(f"Columns with 'pdays': {[col for col in X_test.columns if 'pdays' in col.lower()]}")
else:
    print("\n'pdays2' column not found in X_test")

print(f"\nNow X_train shape: {X_train.shape}")
print(f"Now X_test shape: {X_test.shape}")
print(f"Shapes match: {X_train.shape[1] == X_test.shape[1]}")
# Out:
# Before fixing:
# X_test shape: (22080, 51)
# Columns with 'pdays': ['pdays', 'pdays2']
#
# After removing 'pdays2':
# X_test shape: (22080, 50)
# Columns with 'pdays': ['pdays']
#
# Now X_train shape: (51588, 51)
# Now X_test shape: (22080, 50)
# Shapes match: False

# %%
# Check the columns in X_train and X_test to identify the mismatch
print("X_train columns:")
print(X_train.columns.tolist() if hasattr(X_train, 'columns') else f"X_train shape: {X_train.shape}")
print("\nX_test columns:")
print(X_test.columns.tolist() if hasattr(X_test, 'columns') else f"X_test shape: {X_test.shape}")

# Check if they're different
if hasattr(X_train, 'columns') and hasattr(X_test, 'columns'):
    train_cols = set(X_train.columns)
    test_cols = set(X_test.columns)
    print(f"\nColumns only in X_test: {test_cols - train_cols}")
    print(f"Columns only in X_train: {train_cols - test_cols}")
# Out:
# X_train columns:
# ['age', 'default', 'housing', 'loan', 'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'pdays2', 'job_admin.', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid', 'job_management', 'job_retired', 'job_self-employed', 'job_services', 'job_student', 'job_technician', 'job_unemployed', 'marital_divorced', 'marital_married', 'marital_unknown', 'education_basic.4y', 'education_basic.6y', 'education_basic.9y', 'education_high.school', 'education_illiterate', 'education_professional.course', 'education_university.degree', 'contact_telephone', 'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun', 'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep', 'day_of_week_fri', 'day_of_week_mon', 'day_of_week_thu', 'day_of_week_tue', 'day_of_week_wed']
#
# X_test columns:
# ['age', 'default', 'housing', 'loan', 'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'job_admin.', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid', 'job_management', 'job_retired', 'job_self-employed', 'job_services', 'job_student', 'job_technician', 'job_unemployed', 'marital_divorced', 'marital_married', 'marital_unknown', 'education_basic.4y', 'education_basic.6y', 'education_basic.9y', 'education_high.school', 'education_illiterate', 'education_professional.course', 'education_university.degree', 'contact_telephone', 'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun', 'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep', 'day_of_week_fri', 'day_of_week_mon', 'day_of_week_thu', 'day_of_week_tue', 'day_of_week_wed']
#
# Columns only in X_test: set()
# Columns only in X_train: {'pdays2'}

# %%
# Debug the data types and shapes
print("=== DEBUGGING DATA TYPES AND SHAPES ===")
print(f"X_train type: {type(X_train)}")
print(f"X_test type: {type(X_test)}")
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")

# Check if they have column information
print(f"X_train has columns attribute: {hasattr(X_train, 'columns')}")
print(f"X_test has columns attribute: {hasattr(X_test, 'columns')}")

if hasattr(X_train, 'columns'):
    print(f"X_train columns ({len(X_train.columns)}): {list(X_train.columns)}")
if hasattr(X_test, 'columns'):
    print(f"X_test columns ({len(X_test.columns)}): {list(X_test.columns)}")

# Since there's a feature count mismatch, let's go back to the source data
# and reconstruct X_train and X_test with matching features
print("\n=== RECONSTRUCTING FROM CLEAN DATA ===")

# Use the data_clean and data_clean_1 DataFrames to rebuild properly
y_train_new = data_clean[['y']]
X_train_new = data_clean.drop(['y'], axis=1)

y_test_new = data_clean_1[['y']]  
X_test_new = data_clean_1.drop(['y'], axis=1)

print(f"Original data_clean shape: {data_clean.shape}")
print(f"Original data_clean_1 shape: {data_clean_1.shape}")
print(f"New X_train shape: {X_train_new.shape}")
print(f"New X_test shape: {X_test_new.shape}")

# Check for column differences
train_cols = set(X_train_new.columns)
test_cols = set(X_test_new.columns)
only_in_train = train_cols - test_cols
only_in_test = test_cols - train_cols

print(f"\nColumns only in training data: {list(only_in_train)}")
print(f"Columns only in test data: {list(only_in_test)}")

# Fix the mismatch by ensuring both have the same columns
for col in only_in_test:
    if col in X_test_new.columns:
        X_test_new = X_test_new.drop(columns=[col])
        print(f"Removed '{col}' from X_test")

for col in only_in_train:
    X_test_new[col] = 0
    print(f"Added '{col}' to X_test (filled with 0)")

# Reorder columns to match
X_test_new = X_test_new[X_train_new.columns]

print(f"\nAfter alignment:")
print(f"X_train shape: {X_train_new.shape}")
print(f"X_test shape: {X_test_new.shape}")
print(f"Columns match: {list(X_train_new.columns) == list(X_test_new.columns)}")

# Now apply StandardScaler
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train_new)
X_test = sc_X.transform(X_test_new)

# Update the y variables too
y_train = y_train_new
y_test = y_test_new

print(f"\nAfter scaling:")
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print("StandardScaler applied successfully!")
# Out:
# === DEBUGGING DATA TYPES AND SHAPES ===
# X_train type: <class 'numpy.ndarray'>
# X_test type: <class 'pandas.core.frame.DataFrame'>
# X_train shape: (51588, 51)
# X_test shape: (22080, 50)
# X_train has columns attribute: False
# X_test has columns attribute: True
# X_test columns (50): ['age', 'default', 'housing', 'loan', 'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'job_admin.', 'job_blue-collar', 'job_entrepreneur', 'job_housemaid', 'job_management', 'job_retired', 'job_self-employed', 'job_services', 'job_student', 'job_technician', 'job_unemployed', 'marital_divorced', 'marital_married', 'marital_unknown', 'education_basic.4y', 'education_basic.6y', 'education_basic.9y', 'education_high.school', 'education_illiterate', 'education_professional.course', 'education_university.degree', 'contact_telephone', 'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun', 'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep', 'day_of_week_fri', 'day_of_week_mon', 'day_of_week_thu', 'day_of_week_tue', 'day_of_week_wed']
#
# === RECONSTRUCTING FROM CLEAN DATA ===
# Original data_clean shape: (51588, 52)
# Original data_clean_1 shape: (22080, 52)
# New X_train shape: (51588, 51)
# New X_test shape: (22080, 51)
#
# Columns only in training data: []
# Columns only in test data: []
#
# After alignment:
# X_train shape: (51588, 51)
# X_test shape: (22080, 51)
# Columns match: True
#
# After scaling:
# X_train shape: (51588, 51)
# X_test shape: (22080, 51)
# StandardScaler applied successfully!

# %%
# inport Dummy Classifier for creating Base Model
from sklearn.linear_model import LogisticRegression
classifier_lr = LogisticRegression(random_state=0)
finalModel_lr = Convert_Model(X_train,y_train,X_test,y_test,classifier_lr)
# Out:
# 0.7336050724637682
# [[9230 1738]
#  [4144 6968]]
# 0.7336050724637682
# 0.8003675626005053
# 0.6270698344132469
# f1 score 0.703199111918458
# c:\Users\Jayesh Mahajan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# roc curve and auc on imbalanced dataset
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
probs = finalModel_lr.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
# plot no skill
pyplot.plot([0, 1], [0, 1], linestyle='--')
# plot the precision-recall curve for the model
pyplot.plot(fpr, tpr, marker='.')
# show the plot
pyplot.show()
# Out:
# AUC: 0.787

# %% [markdown]
# # Random Forest Classifier

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
# roc curve and auc on imbalanced dataset
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

# %% [markdown]
# # Training Random Forest Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
rfc = RandomForestClassifier(n_estimators=100)
finalModel_rfc = Convert_Model(X_train,y_train,X_test,y_test,rfc)
# Out:
# c:\Users\Jayesh Mahajan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 0.6614583333333334
# [[10221   747]
#  [ 6728  4384]]
# [[10221   747]
#  [ 6728  4384]]
# 0.6614583333333334
# 0.6614583333333334
# 0.8544143441824206
# 0.8544143441824206
# 0.39452843772498203
# 0.39452843772498203
# f1 score 0.5398017607584806
# f1 score 0.5398017607584806

# %% [markdown]
# # Testing

# %%
probs = finalModel_rfc.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
# plot no skill
pyplot.plot([0, 1], [0, 1], linestyle='--')
# plot the precision-recall curve for the model
pyplot.plot(fpr, tpr, marker='.')
# show the plot
pyplot.show()
# Out:
# AUC: 0.764

# %% [markdown]
# # Feature Importance

# %%
data_clean.head()
# Out:
#             age  default  housing  loan  campaign  pdays  previous  poutcome  \
# 39075  0.000000        1        1     1  0.666667    1.0  0.142857        -1
# 34855  0.000000        1        1     1  1.000000    1.0  0.000000         0
# 7107   0.666667        0       -1     1  0.333333    1.0  0.000000         0
# 31614  0.333333        1        1     1  0.000000    1.0  0.142857        -1
# 34878  0.333333        1        1     1  1.000000    1.0  0.000000         0
#
#        emp.var.rate  cons.price.idx  ...  month_mar  month_may  month_nov  \
# 39075      0.083333        0.199532  ...      False      False      False
# 34855      0.333333        0.269680  ...      False       True      False
# 7107       0.937500        0.698753  ...      False       True      False
# 31614      0.333333        0.269680  ...      False       True      False
# 34878      0.333333        0.269680  ...      False       True      False
#
#        month_oct  month_sep  day_of_week_fri  day_of_week_mon  \
# 39075      False      False            False             True
# 34855      False      False             True            False
# 7107       False      False            False            False
# 31614      False      False            False            False
# 34878      False      False             True            False
#
#        day_of_week_thu  day_of_week_tue  day_of_week_wed
# 39075            False            False            False
# 34855            False            False            False
# 7107              True            False            False
# 31614             True            False            False
# 34878            False            False            False
#
# [5 rows x 52 columns]

# %%
X = data_clean.drop('y', axis=1).values
y = data_clean['y'].values
pp=data_clean.drop('y', axis=1)
x_train, x_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.3, random_state=42)
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)
feature_importances = pd.DataFrame(rfc.feature_importances_,index = pp.columns,columns=['importance']).sort_values('importance',ascending=False)
# Out:
# c:\Users\Jayesh Mahajan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
feature_importances
# Out:
#                                importance
# euribor3m                        0.158044
# campaign                         0.080383
# age                              0.071077
# nr.employed                      0.058139
# emp.var.rate                     0.050642
# housing                          0.043565
# marital_married                  0.031343
# cons.conf.idx                    0.028490
# loan                             0.026994
# cons.price.idx                   0.023721
# default                          0.023249
# pdays                            0.020031
# job_admin.                       0.019749
# contact_telephone                0.018804
# education_high.school            0.018766
# education_university.degree      0.017234
# poutcome                         0.016161
# marital_divorced                 0.016045
# day_of_week_mon                  0.016008
# day_of_week_wed                  0.015809
# job_technician                   0.015748
# day_of_week_fri                  0.015517
# day_of_week_thu                  0.015510
# job_blue-collar                  0.015432
# day_of_week_tue                  0.015197
# education_basic.9y               0.014799
# pdays2                           0.013566
# previous                         0.013119
# education_professional.course    0.012660
# month_may                        0.011654
# job_services                     0.011583
# education_basic.4y               0.010663
# job_management                   0.010406
# education_basic.6y               0.008362
# job_self-employed                0.007682
# job_retired                      0.007271
# job_entrepreneur                 0.006879
# month_oct                        0.005544
# job_student                      0.005247
# job_unemployed                   0.005232
# job_housemaid                    0.005065
# month_mar                        0.004178
# month_apr                        0.002745
# month_jun                        0.002572
# month_jul                        0.002235
# month_aug                        0.002106
# month_nov                        0.001989
# month_sep                        0.001327
# marital_unknown                  0.000743
# month_dec                        0.000411
# education_illiterate             0.000303

# %% [markdown]
# # SVM Classifier

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Choosing the best parameters for SVM classifier based on 2-fold Cross Validation score

# %%
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [0.1], 'C': [1]},
                    {'kernel': ['linear'], 'C': [1]}]

# %%
clf = GridSearchCV(SVC(), tuned_parameters, cv=2, scoring='precision')

# %%
finalModel_gb = Convert_Model(X_train,y_train,X_test,y_test,clf)
# Out:
# c:\Users\Jayesh Mahajan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Jayesh Mahajan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Jayesh Mahajan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Jayesh Mahajan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Jayesh Mahajan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Jayesh Mahajan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Jayesh Mahajan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.7275699979562641
# [[9635 1333]
#  [7552 3560]]
# [[9635 1333]
#  [7552 3560]]
# 0.5975996376811594
# 0.5975996376811594
# 0.7275699979562641
# 0.7275699979562641
# 0.320374370050396
# 0.320374370050396
# f1 score 0.4448609809434552
# f1 score 0.4448609809434552

# %%
print('The best model is: ', finalModel_gb.best_params_)
print('This model produces a mean cross-validated score (precision) of', finalModel_gb.best_score_)
# Out:
# The best model is:  {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# This model produces a mean cross-validated score (precision) of 0.873650257341892

# %% [markdown]
# # Testing

# %%
from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score
y_true, y_pred = y_test, finalModel_gb.predict(X_test)
pre1 = precision_score(y_true, y_pred)
rec1 = recall_score(y_true, y_pred)
acc1 = accuracy_score(y_true, y_pred)
f1_1 = f1_score(y_true, y_pred)
print('precision on the evaluation set: ', pre1)
print('recall on the evaluation set: ', rec1)
print('accuracy on the evaluation set: ', acc1)
print("F1 on the evaluation set",f1_1)
# Out:
# precision on the evaluation set:  0.8888888888888888
# recall on the evaluation set:  0.0014398848092152627
# accuracy on the evaluation set:  0.4973731884057971
# F1 on the evaluation set 0.002875112309074573

# %%
# roc curve and auc on imbalanced dataset
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
probs = finalModel_gb.predict(X_test)
# keep probabilities for the positive outcome only

# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
# plot no skill
pyplot.plot([0, 1], [0, 1], linestyle='--')
# plot the precision-recall curve for the model
pyplot.plot(fpr, tpr, marker='.')
# show the plot
pyplot.show()
# Out:
# AUC: 0.501

# %%
from matplotlib import pyplot as plt
from sklearn import svm
from matplotlib import pyplot as plt
X = data_clean.drop('y', axis=1).values
y = data_clean['y'].values
pp=data_clean.drop('y', axis=1)
x_train, x_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.3, random_state=42)



def f_importances(coef, names, top=-1):
    imp = coef
    imp, names = zip(*sorted(list(zip(imp, names))))

    # Show all features
    if top == -1:
        top = len(names)

    plt.barh(range(top), imp[::-1][0:top], align='center')
    plt.yticks(range(top), names[::-1][0:top])
    plt.show()

# whatever your features are called
features_names = ['age', 'default', 'housing', 'loan', 'campaign', 'pdays', 'previous',
       'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
       'euribor3m', 'nr.employed', 'y', 'pdays2', 'job_admin.',
       'job_blue-collar', 'job_entrepreneur', 'job_housemaid',
       'job_management', 'job_retired', 'job_self-employed', 'job_services',
       'job_student', 'job_technician', 'job_unemployed', 'job_unknown',
       'marital_divorced', 'marital_married', 'marital_single',
       'marital_unknown', 'education_basic.4y', 'education_basic.6y',
       'education_basic.9y', 'education_high.school', 'education_illiterate',
       'education_professional.course', 'education_university.degree',
       'education_unknown', 'contact_cellular', 'contact_telephone',
       'month_apr', 'month_aug', 'month_dec', 'month_jul', 'month_jun',
       'month_mar', 'month_may', 'month_nov', 'month_oct', 'month_sep',
       'day_of_week_fri', 'day_of_week_mon', 'day_of_week_thu',
       'day_of_week_tue', 'day_of_week_wed'] 
svm = svm.SVC(kernel='linear')
svm.fit(X_train, y_train)

# Specify your top n features you want to visualize.
# You can also discard teh abs() function 
# if you are interested in negative contribution of features
f_importances(abs(svm.coef_[0]), features_names, top=10)
# Out:
# c:\Users\Jayesh Mahajan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# Reducing Features using PCA

# %% [markdown]
# # Classify the model using XGBClassifier

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# fit model no training data
model = XGBClassifier()
finalModel_XGB = Convert_Model(X_train,y_train,X_test,y_test,model)
# Out:
# 0.5443840579710145
# [[10852   116]
#  [ 9944  1168]]
# 0.5443840579710145
# 0.9096573208722741
# 0.10511159107271419
# f1 score 0.18844788641497257

# %%
#ROC curve
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
probs = finalModel_XGB.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
# plot no skill
pyplot.plot([0, 1], [0, 1], linestyle='--')
# plot the precision-recall curve for the model
pyplot.plot(fpr, tpr, marker='.')
# show the plot
pyplot.show()
# Out:
# AUC: 0.699

# %%
X = data_clean.drop('y', axis=1).values
y = data_clean['y'].values
pp=data_clean.drop('y', axis=1)
x_train, x_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.3, random_state=42)
rmodel = XGBClassifier()
rmodel.fit(X_train, y_train)
feature_importances = pd.DataFrame(rmodel.feature_importances_,index = pp.columns,columns=['importance']).sort_values('importance',ascending=False)

# %%
feature_importances
# Out:
#                                importance
# nr.employed                      0.553225
# month_oct                        0.044846
# cons.conf.idx                    0.036923
# cons.price.idx                   0.014429
# emp.var.rate                     0.013788
# contact_telephone                0.013317
# pdays                            0.012386
# default                          0.011643
# poutcome                         0.010874
# job_student                      0.009315
# euribor3m                        0.008984
# month_jul                        0.008789
# job_services                     0.008595
# age                              0.008535
# day_of_week_mon                  0.008519
# job_unemployed                   0.008518
# education_professional.course    0.008347
# month_apr                        0.008335
# job_blue-collar                  0.008220
# job_management                   0.008186
# education_basic.4y               0.007869
# job_self-employed                0.007844
# month_may                        0.007797
# loan                             0.007751
# job_entrepreneur                 0.007730
# day_of_week_fri                  0.007693
# day_of_week_wed                  0.007540
# education_university.degree      0.007504
# job_retired                      0.007486
# marital_married                  0.007461
# month_nov                        0.007283
# housing                          0.007274
# job_housemaid                    0.007219
# campaign                         0.007195
# job_technician                   0.007169
# education_high.school            0.007096
# day_of_week_thu                  0.007037
# day_of_week_tue                  0.006967
# marital_divorced                 0.006729
# education_basic.9y               0.006666
# education_basic.6y               0.006346
# month_jun                        0.006165
# job_admin.                       0.005963
# marital_unknown                  0.005744
# previous                         0.005340
# month_sep                        0.004838
# month_aug                        0.004479
# month_mar                        0.003600
# month_dec                        0.002674
# education_illiterate             0.001766

# %% [markdown]
# # MLP **Classifier with 3 layer**

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
seed = 7
test_size = 0.33
mlp = MLPClassifier(hidden_layer_sizes=(13,13,13),max_iter=500)
mlp.fit(X_train,y_train)
# Out:
# c:\Users\Jayesh Mahajan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1124: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MLPClassifier(hidden_layer_sizes=(13, 13, 13), max_iter=500)

# %%
from sklearn.metrics import classification_report,confusion_matrix
predictions = mlp.predict(X_test)
#print the confusion matrix
print(confusion_matrix(y_test,predictions))
# Out:
# [[10373   595]
#  [ 8032  3080]]

# %%
#Print the classification report
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.95      0.71     10968
#            1       0.84      0.28      0.42     11112
#
#     accuracy                           0.61     22080
#    macro avg       0.70      0.61      0.56     22080
# weighted avg       0.70      0.61      0.56     22080

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score


classifier_mlp = MLPClassifier(hidden_layer_sizes=(13,14,15 ) ,max_iter=500)
finalModel_mlp = Convert_Model(X_train,y_train,X_test,y_test,classifier_mlp)
# Out:
# c:\Users\Jayesh Mahajan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1124: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.522373188405797
# [[9934 1034]
#  [9512 1600]]
# 0.522373188405797
# 0.6074411541381929
# 0.14398848092152627
# f1 score 0.23279499490760946

# %%
# roc curve and auc on imbalanced dataset
from sklearn.datasets import make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
probs = finalModel_mlp.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
# plot no skill
pyplot.plot([0, 1], [0, 1], linestyle='--')
# plot the precision-recall curve for the model
pyplot.plot(fpr, tpr, marker='.')
# show the plot
pyplot.show()
# Out:
# AUC: 0.591

# %% [markdown]
# #  MLP Classifier with 2 layer

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score


classifier_mlp = MLPClassifier(hidden_layer_sizes=(13,13 ) ,max_iter=500)
finalModel_mlp = Convert_Model(X_train,y_train,X_test,y_test,classifier_mlp)
# Out:
# c:\Users\Jayesh Mahajan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1124: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5453804347826087
# [[7130 3838]
#  [6200 4912]]
# 0.5453804347826087
# 0.5613714285714285
# 0.44204463642908565
# f1 score 0.49461282851676563

# %%
# roc curve and auc on imbalanced dataset
from sklearn.datasets import make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
probs = finalModel_mlp.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
# plot no skill
pyplot.plot([0, 1], [0, 1], linestyle='--')
# plot the precision-recall curve for the model
pyplot.plot(fpr, tpr, marker='.')
# show the plot
pyplot.show()
# Out:
# AUC: 0.535

# %% [markdown]
# # MLP Classifier with 1 layer

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score


classifier_mlp = MLPClassifier(hidden_layer_sizes=(13 ) ,max_iter=500)
finalModel_mlp = Convert_Model(X_train,y_train,X_test,y_test,classifier_mlp)
# Out:
# c:\Users\Jayesh Mahajan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1124: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.6934782608695652
# [[8888 2080]
#  [4688 6424]]
# 0.6934782608695652
# 0.7554092191909689
# 0.578113750899928
# f1 score 0.6549755301794454

# %%
# roc curve and auc on imbalanced dataset
from sklearn.datasets import make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
probs = finalModel_mlp.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# calculate AUC
auc = roc_auc_score(y_test, probs)
print('AUC: %.3f' % auc)
# calculate roc curve
fpr, tpr, thresholds = roc_curve(y_test, probs)
# plot no skill
pyplot.plot([0, 1], [0, 1], linestyle='--')
# plot the precision-recall curve for the model
pyplot.plot(fpr, tpr, marker='.')
# show the plot
pyplot.show()
# Out:
# AUC: 0.738

# %%
#by balcing y output
# After standardization our f1 score and auc percentage increases
from prettytable import PrettyTable    
x = PrettyTable()
 
x.field_names = ["MODEL", "ACCURACY_score","precision_score","Recall_score","F1 score","AUC"]
x.add_row(["Dummy classifer",0.50, 0.50,1,0.66,"NAN"])
x.add_row(["Logistic Regression)", 0.73, 0.80,0.62,0.70,0.78])
x.add_row(["Random Forest",0.65, 0.85,0.38,0.52,0.766])
x.add_row(["SVM classifier",0.73, 0.82,0.60,0.69,0.73])
x.add_row(["XGB boost",0.74, 0.81,0.63,0.71,0.798])
x.add_row(["MLP  classifier with 3 layers",0.70, 0.74,0.61,0.67,0.745])
x.add_row(["MLP classifier with 2 layers",0.70, 0.75,0.61,0.68,0.76])
x.add_row(["MLP classifier 1 layers",0.72, 0.78,0.62,0.693,0.766])

print('Bank Marketing')
print(x)
# Out:
# Bank Marketing
# +-------------------------------+----------------+-----------------+--------------+----------+-------+
# |             MODEL             | ACCURACY_score | precision_score | Recall_score | F1 score |  AUC  |
# +-------------------------------+----------------+-----------------+--------------+----------+-------+
# |        Dummy classifer        |      0.5       |       0.5       |      1       |   0.66   |  NAN  |
# |      Logistic Regression)     |      0.73      |       0.8       |     0.62     |   0.7    |  0.78 |
# |         Random Forest         |      0.65      |       0.85      |     0.38     |   0.52   | 0.766 |
# |         SVM classifier        |      0.73      |       0.82      |     0.6      |   0.69   |  0.73 |
# |           XGB boost           |      0.74      |       0.81      |     0.63     |   0.71   | 0.798 |
# | MLP  classifier with 3 layers |      0.7       |       0.74      |     0.61     |   0.67   | 0.745 |
# |  MLP classifier with 2 layers |      0.7       |       0.75      |     0.61     |   0.68   |  0.76 |
# |    MLP classifier 1 layers    |      0.72      |       0.78      |     0.62     |  0.693   | 0.766 |
# +-------------------------------+----------------+-----------------+--------------+----------+-------+
